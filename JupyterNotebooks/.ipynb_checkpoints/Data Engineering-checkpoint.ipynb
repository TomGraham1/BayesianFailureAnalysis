# %%
import pandas as pd
import numpy as np

# %%
attributes = pd.read_csv("../project_data/finished_attributes_engineering.csv",names=['SiteID', 'PlotNo', 'CentralAssetID', "AttrHD52","AttrNameHD5","AttrHD41",
"AttrNameHD41",
"AttrHD39",
"AttrNameHD39",
"AttrHD57",
"AttrNameHD57",
"AttrHD51",
"AttrNameHD51",
"AttrHD76",
"AttrNameHD76",
"AttrHD14",
"AttrNameHD14",
"AttrHD06",
"AttrNameHD06",
"AttrHD13",
"AttrNameHD13",
"AttrHD16",
"AttrNameHD16",
"AttrHD17",
"AttrNameHD17",
"AttrHD07",
"AttrNameHD07",
"AttrHD19",
"AttrNameHD19",
"AttrXSP",
"AttrNameXSP",
"AttrHD05",
"AttrNameHD05",
"AttrHD04",
"AttrNameHD04","ExtractTimestamp"], header=None,index_col=False)

# %%
interventions = pd.read_csv("../project_data/interventions_dataset.csv",names=[
"JobID"
,"CentralAssetID"
,"SiteID"
,"PlotNo"
,"AssetTypeID"
,"LogNo"
,"EntryDateTime"
,"Notes"
,"JobTypeID"
,"JobTypeCode"
,"JobTypeName"
,"JobStatusID"
,"FloodHotspot"
,"JobStatusName"
,"PriorityID"
,"PriorityName"
,"ActualStartingDateTime"
,"ActualCompletionDateTime"
,"ActualCompletionYearMonth"
,"RouteID"
,"ParameterTypeID"
,"ParameterValueID"
,"IsDeletedFlag"
,"IsCurrentFlag"
,"ValidFromDateTime"
,"ValidToDateTime"
,"InsertedDateTime"
,"JobItemID"
,"SorItemID"
,"ExtractTimestamp"],header=None,index_col=False)
# Out:
# /home/tgraham/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3106: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
interventions.groupby("CentralAssetID",as_index=False)["JobID"].count()
# Out:
#               CentralAssetID  JobID
# 0       00000000001000000147      3
# 1       00000000001000000148      3
# 2       00000000001000000149      3
# 3       00000000001000000150      3
# 4       00000000001000000151      3
# ...                      ...    ...
# 198251        DRGU/A66000703     12
# 198252        DRGU/A66000704     12
# 198253        DRGU/A66000705     13
# 198254        DRGU/A66000706     13
# 198255        DRGU/A66000707     12
#
# [198256 rows x 2 columns]

# %%
def formatting_failure_vs_maintenance(string): 
    if string.find("B") != -1:
        return 1
    else:
        return 0

interventions["Failure_or_Maintenance"] = interventions["JobTypeCode"].apply(formatting_failure_vs_maintenance)

def create_prefix(siteid):
    return siteid[0:4]

interventions["prefix"] = interventions["SiteID"].apply(create_prefix)

# %%
interventions = interventions[(interventions["IsCurrentFlag"]==1)&(interventions["IsDeletedFlag"]==0)]

# %%
interventions = interventions.groupby(['JobID', 'CentralAssetID','EntryDateTime','Notes','FloodHotspot', 'JobStatusName', 'PriorityID',
       'PriorityName','ActualCompletionDateTime', 'RouteID', 'ParameterTypeID',
       'ParameterValueID', 'ExtractTimestamp', 'Failure_or_Maintenance'],as_index=False)["ValidFromDateTime"].max()

# %%
interventions.drop(columns="ValidFromDateTime",inplace=True)

# %%
interventions

# %%
reactive_data = interventions[interventions["Failure_or_Maintenance"]==1].copy()
cyclic_data = interventions[interventions["Failure_or_Maintenance"]==0].copy()

# %%
key_words_covered = ["covered","leaves","Covered","Leaves","Clear","clear","CLEAR","cleared","CLEARED","clearing","cleaning","Cleaning","tops","top","mouth","mouths",
                     "debris","Debris","swept","Sweep","SWEPT","SWEEP","sweep","uncover","Uncover","grate","Obstruction","obstructed","detritus","Detritus","DETRITUS","Free flow impeded"]
key_words_full = ["empty","Empty","emptying","Emptying","gully cleaning","cleansing","cleaning out","jet","Jet","jetted","Jetted","Jetting","sucking","Sucking","sucker","SUCKER",
                 "sucked","Sucked","Suck","SUCK","suck","vac","blocked","Blocked","blockage","Blockage","unblock","Unblock","blocking","Blockage","Silt","silted","silt","Clean out gully"]
key_words_broken = ["collapsing","sunken","Collapsing","Sunken","Reset","reset","re-setting","Broken","broken","replace",
                    "Replace","collapsed","Collapsed","COLLAPSED","pothole","Pothole","POTHOLE","RESET","fit","Fit","FIT",
                   "Adjust","ADJUST","adjust","repair","Repair","missing","Missing","replacing","Replace","REPLACE","REPLACING",
                   "cracked","Cracked","CRACKED","Sandbag","sandbag","Sandbags","SANDBAG","breaking","Breaking","dislodged","Dislodged","misaligned",
                   "Misaligned","degraded","Degraded","frame","Frame","Rattling","rattling","REPAIR","setting","Setting","re-set","Raise",
                    "Hole","hole","patch","Patch","damage","Damage","rocking","Rocking","sunk","Sunk","SUNK","CCTV","cctv","reseating","collapse",
                   "Reinstate","level with","Level with","unseize","seize","Unseize","Seize","broken","New gully lid required","no lid","No lid","lid open","Lid popped out"]

reactive_data["covered_key_word_count"] = 0
reactive_data["full_key_word_count"] = 0
reactive_data["broken_key_word_count"] = 0 
cyclic_data["covered_key_word_count"] = 0
cyclic_data["full_key_word_count"] = 0
cyclic_data["broken_key_word_count"] = 0 
count = 0
for item in reactive_data["Notes"]:
    count += 1
    count_of_covered_key_words=0
    for key_word in key_words_covered:
        if item.find(key_word) != -1:
            count_of_covered_key_words += 1
    reactive_data.loc[reactive_data["Notes"] == item, "covered_key_word_count"] = count_of_covered_key_words

    count_of_full_key_words=0
    for key_word in key_words_full:
        if item.find(key_word) != -1:
            count_of_full_key_words += 1
    reactive_data.loc[reactive_data["Notes"] == item, "full_key_word_count"] = count_of_full_key_words
    
    count_of_broken_key_words=0
    for key_word in key_words_broken:
        if item.find(key_word) != -1:
            count_of_broken_key_words += 1
    reactive_data.loc[reactive_data["Notes"] == item, "broken_key_word_count"] = count_of_broken_key_words

    if count % 1000 == 0 :
        print(count)
# Out:
# 1000
# 2000
# 3000
# 4000

# %% [markdown]
# ### I am selecting the earliest instance of the job because this will be closest to when the failure occured. -- NO LONGER AN ISSUE - all data is created at the same time, the JobItems are created at the same time

# %%
cyclic_data
# Out:
#            JobID        CentralAssetID                EntryDateTime  \
# 224     40328832      A03PO/DRGU039900  2023-03-23 00:00:00.0000000
# 225     40328833      A03PO/DRGU064784  2023-03-23 00:00:00.0000000
# 226     40328835      A03PO/DRGU010165  2023-03-23 00:00:00.0000000
# 227     40328836      A03PO/DRGU029866  2023-03-23 00:00:00.0000000
# 228     40328837      A03PO/DRGU044845  2023-03-23 00:00:00.0000000
# ...          ...                   ...                          ...
# 568710  58156828  DR/HEA10/DRGU/043753  2023-03-29 00:00:00.0000000
# 568711  58156829  DR/HEA10/DRGU/043747  2023-03-29 00:00:00.0000000
# 568712  58156830  DR/HEA10/DRGU/043748  2023-03-29 00:00:00.0000000
# 568713  58156831  DR/HEA10/DRGU/043746  2023-03-29 00:00:00.0000000
# 568714  58156832  DR/HEA10/DRGU/043718  2023-03-29 00:00:00.0000000
#
#                                                     Notes  FloodHotspot  \
# 224     Gully Emptying and covers cleared (4.3.1.1 - G...             0
# 225     Gully Emptying and covers cleared (4.3.1.1 - G...             0
# 226     Gully Emptying and covers cleared (4.3.1.1 - G...             0
# 227     Gully Emptying and covers cleared (4.3.1.1 - G...             0
# 228     Gully Emptying and covers cleared (4.3.1.1 - G...             0
# ...                                                   ...           ...
# 568710      4.3.1.1 Clean/empty gullies - Central Reserve             0
# 568711      4.3.1.1 Clean/empty gullies - Central Reserve             0
# 568712      4.3.1.1 Clean/empty gullies - Central Reserve             0
# 568713      4.3.1.1 Clean/empty gullies - Central Reserve             0
# 568714      4.3.1.1 Clean/empty gullies - Central Reserve             0
#
#                 JobStatusName PriorityID      PriorityName  \
# 224             Work Complete       1MON           1 Month
# 225             Work Complete       1MON           1 Month
# 226             Work Complete       1MON           1 Month
# 227             Work Complete       1MON           1 Month
# 228             Work Complete       1MON           1 Month
# ...                       ...        ...               ...
# 568710          Work Complete       2MTH  2 Month - Commit
# 568711          Work Complete       2MTH  2 Month - Commit
# 568712  Substantiation Passed       2MTH  2 Month - Commit
# 568713          Work Complete       2MTH  2 Month - Commit
# 568714          Work Complete       2MTH  2 Month - Commit
#
#            ActualCompletionDateTime RouteID ParameterTypeID ParameterValueID  \
# 224     2023-04-03 10:26:34.0000000    A395            %FUL             5075
# 225     2023-04-03 10:18:50.0000000    A395            %FUL             5075
# 226     2023-04-03 13:55:11.0000000    A395            %FUL             5075
# 227     2023-04-03 11:39:52.0000000    A395            %FUL             5075
# 228     2023-04-03 14:40:07.0000000    A395            %FUL             5075
# ...                             ...     ...             ...              ...
# 568710  2023-04-02 22:21:00.0000000    M128            %FUL             2550
# 568711  2023-04-02 22:37:09.0000000    M128            %FUL             2550
# 568712  2023-04-02 22:36:46.0000000    M128            %FUL             2550
# 568713  2023-04-02 22:37:33.0000000    M128            %FUL             2550
# 568714  2023-04-02 22:54:58.0000000    M128            %FUL             2550
#
#                ExtractTimestamp  Failure_or_Maintenance  \
# 224     2023-04-21 10:59:09.627                       0
# 225     2023-04-21 10:59:09.627                       0
# 226     2023-04-21 10:59:09.627                       0
# 227     2023-04-21 10:59:09.627                       0
# 228     2023-04-21 10:59:09.627                       0
# ...                         ...                     ...
# 568710  2023-04-21 10:59:09.627                       0
# 568711  2023-04-21 10:59:09.627                       0
# 568712  2023-04-21 10:59:09.627                       0
# 568713  2023-04-21 10:59:09.627                       0
# 568714  2023-04-21 10:59:09.627                       0
#
#         covered_key_word_count  full_key_word_count  broken_key_word_count
# 224                          0                    0                      0
# 225                          0                    0                      0
# 226                          0                    0                      0
# 227                          0                    0                      0
# 228                          0                    0                      0
# ...                        ...                  ...                    ...
# 568710                       0                    0                      0
# 568711                       0                    0                      0
# 568712                       0                    0                      0
# 568713                       0                    0                      0
# 568714                       0                    0                      0
#
# [563731 rows x 17 columns]

# %%
interventions = pd.concat([reactive_data,cyclic_data])

# %%
interventions
# Out:
#            JobID        CentralAssetID                EntryDateTime  \
# 0       12000016      A12SDRGU00004594  2021-06-18 10:49:31.0000000
# 1       12002351         A12GU00010060  2021-10-26 11:12:15.0000000
# 2       12002726         A12GU00019535  2021-11-24 14:13:39.0000000
# 3       12002785         A12GU00011223  2021-11-29 12:23:36.0000000
# 4       12003189         A12GU00005763  2022-01-05 10:01:55.0000000
# ...          ...                   ...                          ...
# 568710  58156828  DR/HEA10/DRGU/043753  2023-03-29 00:00:00.0000000
# 568711  58156829  DR/HEA10/DRGU/043747  2023-03-29 00:00:00.0000000
# 568712  58156830  DR/HEA10/DRGU/043748  2023-03-29 00:00:00.0000000
# 568713  58156831  DR/HEA10/DRGU/043746  2023-03-29 00:00:00.0000000
# 568714  58156832  DR/HEA10/DRGU/043718  2023-03-29 00:00:00.0000000
#
#                                                     Notes  FloodHotspot  \
# 0              3 x blocked gully EB 1 x WB (DR: Blockage)             0
# 1               Sunken gully needs re-bedding to raise.               0
# 2       Gully grate collapsed lower than road (DR: Dra...             0
# 3       1 sunken gully requires resetting in lane 1 M1...             0
# 4       Clean test and prove gullies. Remove thermopla...             0
# ...                                                   ...           ...
# 568710      4.3.1.1 Clean/empty gullies - Central Reserve             0
# 568711      4.3.1.1 Clean/empty gullies - Central Reserve             0
# 568712      4.3.1.1 Clean/empty gullies - Central Reserve             0
# 568713      4.3.1.1 Clean/empty gullies - Central Reserve             0
# 568714      4.3.1.1 Clean/empty gullies - Central Reserve             0
#
#                 JobStatusName PriorityID            PriorityName  \
# 0                  Job Closed       24HR                24 Hours
# 1                  Job Closed       28DY                 28 days
# 2               Work Complete          R  * Priority - Change Me
# 3               Work Complete       28DY                 28 days
# 4               Work Complete       28DY                 28 days
# ...                       ...        ...                     ...
# 568710          Work Complete       2MTH        2 Month - Commit
# 568711          Work Complete       2MTH        2 Month - Commit
# 568712  Substantiation Passed       2MTH        2 Month - Commit
# 568713          Work Complete       2MTH        2 Month - Commit
# 568714          Work Complete       2MTH        2 Month - Commit
#
#            ActualCompletionDateTime RouteID ParameterTypeID ParameterValueID  \
# 0       2021-06-19 08:07:55.0000000    NO76            %FUL             7510
# 1       2021-11-09 04:03:52.0000000    NO96            %FUL             0-25
# 2       2021-11-24 14:18:34.0000000    NO87            %FUL             2550
# 3       2021-12-08 07:31:56.0000000    NO87            %FUL               NK
# 4       2022-07-26 01:01:43.0000000    NO41            %FUL             7510
# ...                             ...     ...             ...              ...
# 568710  2023-04-02 22:21:00.0000000    M128            %FUL             2550
# 568711  2023-04-02 22:37:09.0000000    M128            %FUL             2550
# 568712  2023-04-02 22:36:46.0000000    M128            %FUL             2550
# 568713  2023-04-02 22:37:33.0000000    M128            %FUL             2550
# 568714  2023-04-02 22:54:58.0000000    M128            %FUL             2550
#
#                ExtractTimestamp  Failure_or_Maintenance  \
# 0       2023-04-21 10:59:09.627                       1
# 1       2023-04-21 10:59:09.627                       1
# 2       2023-04-21 10:59:09.627                       1
# 3       2023-04-21 10:59:09.627                       1
# 4       2023-04-21 10:59:09.627                       1
# ...                         ...                     ...
# 568710  2023-04-21 10:59:09.627                       0
# 568711  2023-04-21 10:59:09.627                       0
# 568712  2023-04-21 10:59:09.627                       0
# 568713  2023-04-21 10:59:09.627                       0
# 568714  2023-04-21 10:59:09.627                       0
#
#         covered_key_word_count  full_key_word_count  broken_key_word_count
# 0                            0                    3                      0
# 1                            0                    0                      2
# 2                            1                    0                      3
# 3                            1                    0                      5
# 4                            2                    0                      2
# ...                        ...                  ...                    ...
# 568710                       0                    0                      0
# 568711                       0                    0                      0
# 568712                       0                    0                      0
# 568713                       0                    0                      0
# 568714                       0                    0                      0
#
# [568716 rows x 17 columns]

# %%
interventions["full_key_word_count"].value_counts()
# Out:
# 0    565486
# 1      1096
# 3       879
# 2       727
# 4       350
# 5        75
# 6        70
# 8        26
# 7         6
# 9         1
# Name: full_key_word_count, dtype: int64

# %%
interventions[(interventions["ParameterValueID"] == "7510")&(interventions["Failure_or_Maintenance"]==1)]["full_key_word_count"].value_counts()
# Out:
# 1    385
# 3    320
# 0    259
# 2    242
# 4     95
# 6     50
# 5     39
# 8     24
# 7      5
# 9      1
# Name: full_key_word_count, dtype: int64

# %% [markdown]
# Below shows all the gullies which were between 75%-100% full when inspected but the text analysis does not classify it as a full gully. This could be due to the gully not being "observed" to be full or it could be due to it being towards the bottom of the range and it is still functional say in the 75-85% full range

# %%
for index, row in interventions[(interventions["ParameterValueID"] == "7510")&(interventions["Failure_or_Maintenance"]==1)&(interventions["full_key_word_count"]==0)][0:50].iterrows():
    print(row["Notes"])
# Out:
# Clean test and prove gullies. Remove thermoplastic from the gully tops for them to be opened to carry out maintenance.  Renew any gully frames and lids that are seized Please provide photo evidence of any gullies that are filled with tarmac and road plainings.
# Replace missing gully lid. Will require breaking out kerb to install new size gully. Remove ID cone from site once works are complete.  SEE PICTURE ATTACHED FOR DEFECT
# Investigate flooding problem & rectify if possible. If not produce a report on the issues,.
# Reset / replace gully frame & lid & patch surfacing. 1M x 1M  x 100mm. L1 closure
# NS Gulley grating (split triangle) broken  (500mm x 500mm) - requires replacing (DR: Loose/Rocking Cover)
# Perm repair: replace drainage cover. Has been made safe and marked with cone.
# IN: Drainage Systems - 2 DRAINS + CHAMBER THAT NEEDS CLEARING - THE CHAMBER HAS A YELLOW SANDBAG AND THE DRAINS HAVE DEBRIS ON THEM - NEEDS CLEARING FOR THE INCOMING RAINS  (Enquiry 37108196)
# Free flow impeded in 15 x nearside gullies, affected by vegetation growth and detritus (Drainage Defect) All gullys to be cleared in closure
# Kerb gully requires reseating, hexagon locking key required. This is the 8th gully out of nine counting from the start of the layby. AWS sign at start of layby. (Drainage Defect)
# 12 x OFFSIDE gullies *in flood check area* badly affected by recent leaf fall, scraping of 12 x gully tops or 600 metres of offside kerb sweeping required to ensure free flow is restored L4C3=12 - 28 days (Drainage Defect)
# Weed growth needs clearing from side entry drainage, due to being in high risk flood area. (Drainage Defect) Clean all gullies location section on nearside.
# Live lane flooding Made safe by reinstating grip. Enquiry 37115398 flood event. (Drainage Defect)
# Standing water in live lane (Drainage Defect)
# GULLYS COVERED NOT LETTING WATER BE RELEASED 17 GULLYS TO BE SWEPT OF DEBRIS/SILT AND LEAVES  AND DISPOSED OF WASTE C = MEDIUM L = MEDIUM (Drainage Defect)
# CR VChannel filled with detritus, requires sweeping L3 C3 T9 (Drainage Defect)
# Broken and sunken gully top.  SP to make safe , require a new gully top.  C =4 L=4 T =16 (Drainage Defect)
# Gully grating collapsing and frame loose Replace Gully grating and frame and reinstate Surfacing (DR: Drainage Collapsed)
# Pothole around gully and the gully cover is loose. (DR: Loose/Rocking Cover)
# Gully cover is loose and has a pothole around it. (DR: Loose/Rocking Cover)
# Gully has sunk significantly - requires reinstatement within 3 months (DR: Loose/Rocking Cover)
# Gully cover off frame Put back gully on frame in 24 hours (DR: Chamber/benching/pot defec)
# Gully cover not on frame Put gully cover on frame in 24 hours (DR: Chamber/benching/pot defec)
# Drainage gully cover loose. Surround has failed,  exposing iron work.  Make safe within 24hrs. (DR: Loose/Rocking Cover)
# Loose gully cover due to broken concrete around metal work caused by HGV in Layby  Make safe and resecure gully cover (DR: Loose/Rocking Cover)
# Renew gully frame and cover within 28 days to be programmed in with scheduled surfacing works in the area (DR: Drainage Collapsed)
# Gully lid damaged in centre. Make Safe within 24 hours (DR: Grating/Cover Missing)
# This plus 5 gulleys ravelling east require clearing, heavy rain forecast this weekend. (DR: Deformation In Pipe)
# 35 gullys, between 70/2 and 69/6 need vegitation clearing and returning to full opperational readiness.  (Enquiry 37105743)
# Gully cover off frame Centre of roundabout Reset gully cover onto frame in 24 hours (DR: Grating/Cover Missing)
# Clear x19 gully covers and aprons (defects linked), removing waste from site.  IPV to be used for all locations.
# 1x sunken gully on the nearside - please repair in 3 months (DR: Drainage Collapsed) - Renew gully frame and cover within 3 months
# Drainage Defect
# Drainage Defect
# Drainage Defect
# Drainage Defect
# IN: Flooding -  CARRY OUT GULLY CLEANSING WITHIN THE NEARSIDE CHANNEL THAT HAS BEEN CLEARED OF DETRITUS , CLEAR A SWATHE CUT TO EXTENTS OF CHANNEL CLEARANCE TO PREVENT OVERHANGING VEGETATION FROM BLOCKING THE V CHANNEL - SWEEPER AND GULLY EMPTIER ALLOWED FOR ON JOB   - FLOODING LANE 1 (Enquiry 37111169) -
# Coned missing gully cover Replace cover side entry in 28days . Due to no data on CONFIRM please double check size and update CONFIRM .  (Drainage Defect)
# 3x gullies required clearing on nearside v-channel (Drainage Defect)
# Gulley top missing and damage apron requires urgent repair risk matrix 16  Will require TM dangerous section of road to work on. (Drainage Defect)
# Gully top and chamber filled with soil and debris causing flooding in wet conditions - gully top and chamber to be cleared within 28 days L-3 C-4 S-12 (Drainage Defect)
# Gully top and chamber filled with soil and debris causing flooding in wet conditions - gully top and chamber to be cleared within 28 days L-3 C-4 S-12 (Drainage Defect)
# Carriageway surface totally degraded around all sides of gully this needs patching imedeatly as it posses a serious hazard to motor bikes and cyclists (Drainage Defect)
# Cleared gulley from flood (Drainage Defect)
# No SOR item for Beany Block inspection unit IPV on parent job and schedule 'D' for the replacement block.   (Drainage Defect)
#  PERMANENT REPAIR - adjust levels of existing frame and cover and repair surrounds. Carriageway surface around gully cover degraded and missing, this needs Patching. And is a serious hazard for moter cyclists and cyclists (Pavement Defect) - please refer to A&A and utilise upcoming cyclic closure to complete ironwork defects(Drainage Defect)
# Permanent repair to failing gully surrounds (Pavement Defect) utilise existing iron work, reset at appropriate level and reinstate surrounds to standard.
# (Gully) 1 No. New gully lid required 460mm x 460mm and gully cart. Existing gully lid seized and dropped by 50mm. White cross across the top of gully. SEE TM ON JOB 41402150 - All works are to comply with CDM 2015 requirements and all relevant health & safety legislation.
# (Gully) 2 No. New gully lids required to replace seized lids - All works are to comply with CDM 2015 requirements and all relevant health & safety legislation.
# Gullies and Channel need cleaning (DR: Inadequately drained)
# Take up and reset gully cover and frame (DR: Loose/Rocking Cover)

# %%
text_analysis_quality = interventions[interventions["Failure_or_Maintenance"]==1]

# %%
text_analysis_quality
# Out:
#            JobID        CentralAssetID                EntryDateTime  \
# 0       12000016      A12SDRGU00004594  2021-06-18 10:49:31.0000000
# 1       12002351         A12GU00010060  2021-10-26 11:12:15.0000000
# 2       12002726         A12GU00019535  2021-11-24 14:13:39.0000000
# 3       12002785         A12GU00011223  2021-11-29 12:23:36.0000000
# 4       12003189         A12GU00005763  2022-01-05 10:01:55.0000000
# ...          ...                   ...                          ...
# 566320  58148171  DR/HEA10/DRGU/000546  2022-12-07 10:44:46.0000000
# 566321  58148241  DR/HEA10/DRGU/034430  2022-12-09 13:55:58.0000000
# 566322  58148955  DR/HEA10/DRGU/024896  2022-12-28 10:01:08.0000000
# 566323  58149402  DR/HEA10/DRGU/034212  2023-01-15 08:59:55.0000000
# 568715  58165003  DR/HEA10/DRGU/018579  2023-04-13 12:57:34.0000000
#
#                                                     Notes  FloodHotspot  \
# 0              3 x blocked gully EB 1 x WB (DR: Blockage)             0
# 1               Sunken gully needs re-bedding to raise.               0
# 2       Gully grate collapsed lower than road (DR: Dra...             0
# 3       1 sunken gully requires resetting in lane 1 M1...             0
# 4       Clean test and prove gullies. Remove thermopla...             0
# ...                                                   ...           ...
# 566320  MAKE SAFE x 1 blocked gully - NS kerb Located ...             0
# 566321  Lid/Cover Broken or Seized 4.3.1.1 Gullies; gu...             0
# 566322  Offside gully channel blocked, needs clearing....             0
# 566323  Flooding  Gully cover cleared of debris (Drain...             0
# 568715             Reset wier gully lid (Drainage Defect)             0
#
#         JobStatusName PriorityID            PriorityName  \
# 0          Job Closed       24HR                24 Hours
# 1          Job Closed       28DY                 28 days
# 2       Work Complete          R  * Priority - Change Me
# 3       Work Complete       28DY                 28 days
# 4       Work Complete       28DY                 28 days
# ...               ...        ...                     ...
# 566320  Work Complete       24HR                24 Hours
# 566321  Work Complete       2MON                2 Months
# 566322  Work Complete       24HC       24 Hours - Commit
# 566323  Work Complete       FNOW      Fix Now - Internal
# 568715  Work Complete       FNOW      Fix Now - Internal
#
#            ActualCompletionDateTime RouteID ParameterTypeID ParameterValueID  \
# 0       2021-06-19 08:07:55.0000000    NO76            %FUL             7510
# 1       2021-11-09 04:03:52.0000000    NO96            %FUL             0-25
# 2       2021-11-24 14:18:34.0000000    NO87            %FUL             2550
# 3       2021-12-08 07:31:56.0000000    NO87            %FUL               NK
# 4       2022-07-26 01:01:43.0000000    NO41            %FUL             7510
# ...                             ...     ...             ...              ...
# 566320  2022-12-07 12:04:06.0000000    M004            %FUL             7510
# 566321  2023-04-13 11:02:52.0000000    M112            %FUL             0-25
# 566322  2022-12-28 15:27:59.0000000    M092            %FUL             CLEA
# 566323  2023-01-15 09:02:10.0000000    M111            %FUL             0-25
# 568715  2023-04-13 12:58:51.0000000    M015            %FUL             CLEA
#
#                ExtractTimestamp  Failure_or_Maintenance  \
# 0       2023-04-21 10:59:09.627                       1
# 1       2023-04-21 10:59:09.627                       1
# 2       2023-04-21 10:59:09.627                       1
# 3       2023-04-21 10:59:09.627                       1
# 4       2023-04-21 10:59:09.627                       1
# ...                         ...                     ...
# 566320  2023-04-21 10:59:09.627                       1
# 566321  2023-04-21 10:59:09.627                       1
# 566322  2023-04-21 10:59:09.627                       1
# 566323  2023-04-21 10:59:09.627                       1
# 568715  2023-04-21 10:59:09.627                       1
#
#         covered_key_word_count  full_key_word_count  broken_key_word_count
# 0                            0                    1                      0
# 1                            0                    0                      1
# 2                            1                    0                      1
# 3                            1                    0                      1
# 4                            1                    0                      1
# ...                        ...                  ...                    ...
# 566320                       0                    1                      0
# 566321                       1                    1                      1
# 566322                       1                    1                      0
# 566323                       1                    0                      0
# 568715                       0                    0                      1
#
# [4985 rows x 17 columns]

# %%
text_analysis_quality["Full_or_Not"] = text_analysis_quality["ParameterValueID"].apply(lambda x: 1 if x == "7510" else 0)
# Out:
# /tmp/ipykernel_42849/3432591412.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_analysis_quality["Full_or_Not"] = text_analysis_quality["ParameterValueID"].apply(lambda x: 1 if x == "7510" else 0)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
y_true = text_analysis_quality["Full_or_Not"]
y_pred = text_analysis_quality["full_key_word_count"]
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()

# %%
y_pred.value_counts()
# Out:
# 1    3230
# 0    1755
# Name: full_key_word_count, dtype: int64

# %%
y_true.value_counts()
# Out:
# 0    3565
# 1    1420
# Name: Full_or_Not, dtype: int64

# %% [markdown]
# ### Initially Change 1 to zero for full_key_word_count which = 1 and ParameterValueID != 7510
# <br> We have confidence that this is the case as a gully cannot be blocked and full up with debris as well the measured fullness not being 75-100%

# %%
for index, row in text_analysis_quality.iterrows():
    if row["full_key_word_count"] > 0 and row["ParameterValueID"] != '7510':
            text_analysis_quality.loc[index, "full_key_word_count"] = 0
# Out:
# /home/tgraham/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
for item in text_analysis_quality[(text_analysis_quality["ParameterValueID"]=='7510')&(text_analysis_quality["full_key_word_count"] == 0)]["Notes"][0:50]:
    print(item)
# Out:
# Clean test and prove gullies. Remove thermoplastic from the gully tops for them to be opened to carry out maintenance.  Renew any gully frames and lids that are seized Please provide photo evidence of any gullies that are filled with tarmac and road plainings.
# Replace missing gully lid. Will require breaking out kerb to install new size gully. Remove ID cone from site once works are complete.  SEE PICTURE ATTACHED FOR DEFECT
# Investigate flooding problem & rectify if possible. If not produce a report on the issues,.
# Reset / replace gully frame & lid & patch surfacing. 1M x 1M  x 100mm. L1 closure
# NS Gulley grating (split triangle) broken  (500mm x 500mm) - requires replacing (DR: Loose/Rocking Cover)
# Perm repair: replace drainage cover. Has been made safe and marked with cone.
# IN: Drainage Systems - 2 DRAINS + CHAMBER THAT NEEDS CLEARING - THE CHAMBER HAS A YELLOW SANDBAG AND THE DRAINS HAVE DEBRIS ON THEM - NEEDS CLEARING FOR THE INCOMING RAINS  (Enquiry 37108196)
# Free flow impeded in 15 x nearside gullies, affected by vegetation growth and detritus (Drainage Defect) All gullys to be cleared in closure
# Kerb gully requires reseating, hexagon locking key required. This is the 8th gully out of nine counting from the start of the layby. AWS sign at start of layby. (Drainage Defect)
# 12 x OFFSIDE gullies *in flood check area* badly affected by recent leaf fall, scraping of 12 x gully tops or 600 metres of offside kerb sweeping required to ensure free flow is restored L4C3=12 - 28 days (Drainage Defect)
# Weed growth needs clearing from side entry drainage, due to being in high risk flood area. (Drainage Defect) Clean all gullies location section on nearside.
# Live lane flooding Made safe by reinstating grip. Enquiry 37115398 flood event. (Drainage Defect)
# Standing water in live lane (Drainage Defect)
# GULLYS COVERED NOT LETTING WATER BE RELEASED 17 GULLYS TO BE SWEPT OF DEBRIS/SILT AND LEAVES  AND DISPOSED OF WASTE C = MEDIUM L = MEDIUM (Drainage Defect)
# CR VChannel filled with detritus, requires sweeping L3 C3 T9 (Drainage Defect)
# Broken and sunken gully top.  SP to make safe , require a new gully top.  C =4 L=4 T =16 (Drainage Defect)
# Gully grating collapsing and frame loose Replace Gully grating and frame and reinstate Surfacing (DR: Drainage Collapsed)
# Pothole around gully and the gully cover is loose. (DR: Loose/Rocking Cover)
# Gully cover is loose and has a pothole around it. (DR: Loose/Rocking Cover)
# Gully has sunk significantly - requires reinstatement within 3 months (DR: Loose/Rocking Cover)
# Gully cover off frame Put back gully on frame in 24 hours (DR: Chamber/benching/pot defec)
# Gully cover not on frame Put gully cover on frame in 24 hours (DR: Chamber/benching/pot defec)
# Drainage gully cover loose. Surround has failed,  exposing iron work.  Make safe within 24hrs. (DR: Loose/Rocking Cover)
# Loose gully cover due to broken concrete around metal work caused by HGV in Layby  Make safe and resecure gully cover (DR: Loose/Rocking Cover)
# Renew gully frame and cover within 28 days to be programmed in with scheduled surfacing works in the area (DR: Drainage Collapsed)
# Gully lid damaged in centre. Make Safe within 24 hours (DR: Grating/Cover Missing)
# This plus 5 gulleys ravelling east require clearing, heavy rain forecast this weekend. (DR: Deformation In Pipe)
# 35 gullys, between 70/2 and 69/6 need vegitation clearing and returning to full opperational readiness.  (Enquiry 37105743)
# Gully cover off frame Centre of roundabout Reset gully cover onto frame in 24 hours (DR: Grating/Cover Missing)
# Clear x19 gully covers and aprons (defects linked), removing waste from site.  IPV to be used for all locations.
# 1x sunken gully on the nearside - please repair in 3 months (DR: Drainage Collapsed) - Renew gully frame and cover within 3 months
# Drainage Defect
# Drainage Defect
# Drainage Defect
# Drainage Defect
# IN: Flooding -  CARRY OUT GULLY CLEANSING WITHIN THE NEARSIDE CHANNEL THAT HAS BEEN CLEARED OF DETRITUS , CLEAR A SWATHE CUT TO EXTENTS OF CHANNEL CLEARANCE TO PREVENT OVERHANGING VEGETATION FROM BLOCKING THE V CHANNEL - SWEEPER AND GULLY EMPTIER ALLOWED FOR ON JOB   - FLOODING LANE 1 (Enquiry 37111169) -
# Coned missing gully cover Replace cover side entry in 28days . Due to no data on CONFIRM please double check size and update CONFIRM .  (Drainage Defect)
# 3x gullies required clearing on nearside v-channel (Drainage Defect)
# Gulley top missing and damage apron requires urgent repair risk matrix 16  Will require TM dangerous section of road to work on. (Drainage Defect)
# Gully top and chamber filled with soil and debris causing flooding in wet conditions - gully top and chamber to be cleared within 28 days L-3 C-4 S-12 (Drainage Defect)
# Gully top and chamber filled with soil and debris causing flooding in wet conditions - gully top and chamber to be cleared within 28 days L-3 C-4 S-12 (Drainage Defect)
# Carriageway surface totally degraded around all sides of gully this needs patching imedeatly as it posses a serious hazard to motor bikes and cyclists (Drainage Defect)
# Cleared gulley from flood (Drainage Defect)
# No SOR item for Beany Block inspection unit IPV on parent job and schedule 'D' for the replacement block.   (Drainage Defect)
#  PERMANENT REPAIR - adjust levels of existing frame and cover and repair surrounds. Carriageway surface around gully cover degraded and missing, this needs Patching. And is a serious hazard for moter cyclists and cyclists (Pavement Defect) - please refer to A&A and utilise upcoming cyclic closure to complete ironwork defects(Drainage Defect)
# Permanent repair to failing gully surrounds (Pavement Defect) utilise existing iron work, reset at appropriate level and reinstate surrounds to standard.
# (Gully) 1 No. New gully lid required 460mm x 460mm and gully cart. Existing gully lid seized and dropped by 50mm. White cross across the top of gully. SEE TM ON JOB 41402150 - All works are to comply with CDM 2015 requirements and all relevant health & safety legislation.
# (Gully) 2 No. New gully lids required to replace seized lids - All works are to comply with CDM 2015 requirements and all relevant health & safety legislation.
# Gullies and Channel need cleaning (DR: Inadequately drained)
# Take up and reset gully cover and frame (DR: Loose/Rocking Cover)

# %% [markdown]
# ### Due to us now having a validation mechanism of the % full we can cast a winder net to capture more full gullies with the new confidence that a gully will not be classified as full if it is not between 75-100% full

# %%
key_words_covered = ["covered","leaves","Covered","Leaves","Clear","clear","CLEAR","cleared","CLEARED","clearing","cleaning","top blocked","Cleaning","mouth","mouths",
                     "debris","Debris","swept","Sweep","SWEPT","SWEEP","sweep","uncover","Uncover","grate","Obstruction","obstructed","detritus","Detritus","DETRITUS",
                     "Free flow impeded","Fix now","leaf","leaves","Fall","fall","Clear blocked gully grating","clear covers","Clear gully cover","Blocked gully tops"]
key_words_full = ["empty","Empty","emptying","Emptying","gully cleaning","cleansing","cleaning out","jet","Jet","jetted","Jetted","Jetting","sucking","Sucking","sucker","SUCKER",
                 "sucked","Sucked","Suck","SUCK","suck","vac","blocked","Blocked","blockage","Blockage","unblock","Unblock","blocking","Blockage","Silt","silted","silt","Clean out gully","Flooding","flooding","filled","Soil"
                 ,"Cleared","debris","Debris","clearing","detritus","cleaning","CLEARING","FLOOD","BLOCKED","Standing water","standing","Please clear 8 gullies","full of mud"]
key_words_broken = ["collapsing","sunken","Collapsing","Sunken","Reset","reset","re-setting","Broken","broken","replace",
                    "Replace","collapsed","Collapsed","COLLAPSED","pothole","Pothole","POTHOLE","RESET","fit","Fit","FIT",
                   "Adjust","ADJUST","adjust","repair","Repair","missing","Missing","replacing","Replace","REPLACE","REPLACING",
                   "cracked","Cracked","CRACKED","Sandbag","sandbag","Sandbags","SANDBAG","breaking","Breaking","dislodged","Dislodged","misaligned",
                   "Misaligned","degraded","Degraded","frame","Frame","Rattling","rattling","REPAIR","setting","Setting","re-set","Raise",
                    "Hole","hole","patch","Patch","damage","Damage","rocking","Rocking","sunk","Sunk","SUNK","CCTV","cctv","reseating","collapse",
                   "Reinstate","level with","Level with","unseize","seize","Unseize","Seize","broken","New gully lid required","no lid","No lid","lid open","Lid popped out"]

text_analysis_quality["covered_key_word_count"] = 0
text_analysis_quality["full_key_word_count"] = 0
text_analysis_quality["broken_key_word_count"] = 0 
count = 0
for item in reactive_data["Notes"]:
    count += 1
    count_of_covered_key_words=0
    for key_word in key_words_covered:
        if item.find(key_word) != -1:
            count_of_covered_key_words += 1
    text_analysis_quality.loc[text_analysis_quality["Notes"] == item, "covered_key_word_count"] = count_of_covered_key_words

    count_of_full_key_words=0
    for key_word in key_words_full:
        if item.find(key_word) != -1:
            count_of_full_key_words += 1
    text_analysis_quality.loc[text_analysis_quality["Notes"] == item, "full_key_word_count"] = count_of_full_key_words
    
    count_of_broken_key_words=0
    for key_word in key_words_broken:
        if item.find(key_word) != -1:
            count_of_broken_key_words += 1
    text_analysis_quality.loc[text_analysis_quality["Notes"] == item, "broken_key_word_count"] = count_of_broken_key_words

    if count % 1000 == 0 :
        print(count)
# Out:
# /tmp/ipykernel_42849/55841440.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_analysis_quality["covered_key_word_count"] = 0
# /tmp/ipykernel_42849/55841440.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_analysis_quality["full_key_word_count"] = 0
# /tmp/ipykernel_42849/55841440.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   text_analysis_quality["broken_key_word_count"] = 0
# 1000
# 2000
# 3000
# 4000

# %%
for item in text_analysis_quality[(text_analysis_quality["ParameterValueID"]=='7510')&(text_analysis_quality["full_key_word_count"] == 0)]["Notes"][0:500]:
    print(item)
# Out:
# Replace missing gully lid. Will require breaking out kerb to install new size gully. Remove ID cone from site once works are complete.  SEE PICTURE ATTACHED FOR DEFECT
# Reset / replace gully frame & lid & patch surfacing. 1M x 1M  x 100mm. L1 closure
# NS Gulley grating (split triangle) broken  (500mm x 500mm) - requires replacing (DR: Loose/Rocking Cover)
# Perm repair: replace drainage cover. Has been made safe and marked with cone.
# Kerb gully requires reseating, hexagon locking key required. This is the 8th gully out of nine counting from the start of the layby. AWS sign at start of layby. (Drainage Defect)
# 12 x OFFSIDE gullies *in flood check area* badly affected by recent leaf fall, scraping of 12 x gully tops or 600 metres of offside kerb sweeping required to ensure free flow is restored L4C3=12 - 28 days (Drainage Defect)
# GULLYS COVERED NOT LETTING WATER BE RELEASED 17 GULLYS TO BE SWEPT OF DEBRIS/SILT AND LEAVES  AND DISPOSED OF WASTE C = MEDIUM L = MEDIUM (Drainage Defect)
# Broken and sunken gully top.  SP to make safe , require a new gully top.  C =4 L=4 T =16 (Drainage Defect)
# Gully grating collapsing and frame loose Replace Gully grating and frame and reinstate Surfacing (DR: Drainage Collapsed)
# Pothole around gully and the gully cover is loose. (DR: Loose/Rocking Cover)
# Gully cover is loose and has a pothole around it. (DR: Loose/Rocking Cover)
# Gully has sunk significantly - requires reinstatement within 3 months (DR: Loose/Rocking Cover)
# Gully cover off frame Put back gully on frame in 24 hours (DR: Chamber/benching/pot defec)
# Gully cover not on frame Put gully cover on frame in 24 hours (DR: Chamber/benching/pot defec)
# Drainage gully cover loose. Surround has failed,  exposing iron work.  Make safe within 24hrs. (DR: Loose/Rocking Cover)
# Loose gully cover due to broken concrete around metal work caused by HGV in Layby  Make safe and resecure gully cover (DR: Loose/Rocking Cover)
# Renew gully frame and cover within 28 days to be programmed in with scheduled surfacing works in the area (DR: Drainage Collapsed)
# Gully lid damaged in centre. Make Safe within 24 hours (DR: Grating/Cover Missing)
# Gully cover off frame Centre of roundabout Reset gully cover onto frame in 24 hours (DR: Grating/Cover Missing)
# Clear x19 gully covers and aprons (defects linked), removing waste from site.  IPV to be used for all locations.
# 1x sunken gully on the nearside - please repair in 3 months (DR: Drainage Collapsed) - Renew gully frame and cover within 3 months
# Drainage Defect
# Drainage Defect
# Drainage Defect
# Drainage Defect
# Coned missing gully cover Replace cover side entry in 28days . Due to no data on CONFIRM please double check size and update CONFIRM .  (Drainage Defect)
# Gulley top missing and damage apron requires urgent repair risk matrix 16  Will require TM dangerous section of road to work on. (Drainage Defect)
# Carriageway surface totally degraded around all sides of gully this needs patching imedeatly as it posses a serious hazard to motor bikes and cyclists (Drainage Defect)
# No SOR item for Beany Block inspection unit IPV on parent job and schedule 'D' for the replacement block.   (Drainage Defect)
#  PERMANENT REPAIR - adjust levels of existing frame and cover and repair surrounds. Carriageway surface around gully cover degraded and missing, this needs Patching. And is a serious hazard for moter cyclists and cyclists (Pavement Defect) - please refer to A&A and utilise upcoming cyclic closure to complete ironwork defects(Drainage Defect)
# Permanent repair to failing gully surrounds (Pavement Defect) utilise existing iron work, reset at appropriate level and reinstate surrounds to standard.
# (Gully) 1 No. New gully lid required 460mm x 460mm and gully cart. Existing gully lid seized and dropped by 50mm. White cross across the top of gully. SEE TM ON JOB 41402150 - All works are to comply with CDM 2015 requirements and all relevant health & safety legislation.
# (Gully) 2 No. New gully lids required to replace seized lids - All works are to comply with CDM 2015 requirements and all relevant health & safety legislation.
# Take up and reset gully cover and frame (DR: Loose/Rocking Cover)
# RE. Replace damaged gully grate (DR: Grating/Cover Missing)
# To un-seize gully lid reported by Tim Sullivan jnr. To also ensure gully is clear and running freely..
# To un-seize gully lid reported by Tim Sullivan jnr. To also ensure gully is clear and running freely..
# 2x manhole to be reset  and  1 new 600 x 600 square lid to be provided. (MI: Other (Add Description))
# LE. Please carry out drainage investigation works to determine location of suspected broken pipe (DR: Drainage Collapsed)
# Replace manhole cover, see attached for pic, TM included in job no 42116295
# Please can use a root cutter at location 1 (the pipe is 150mm) the gully is in the bus stop and also can we please clear any slit from the oulet where the star is and can we also supply Traffic lights
# Replace gully cover and frame & .8mm2 surround, TM and STATS are on job no 42301330
# please supply and fit new gully frame and cover, replacing any brickwork required in chamber construction.
# Please rebuild benching replace gully frame/cover reinstate to proper level. Please also clear loose material around next gully reinstate around frame to proper level. (DR: Chamber/benching/pot defec)
# Failed repair from 2nd June 2021. Previous confirm 21012071  Loose grate lid and sunken instamac temp repair. Re fill pothole surrounding gully as repair too shallow. Lid to be reset/replace as causing noise disturbance to residents day and night. (DR: Loose/Rocking Cover)
#  Replace gully grating & surround 3m2 x 100mm
# Gully lid and frame broken and collapsed. Please make safe with sandbags and cone off. (DR: Drainage Collapsed)
# Please can we clear all drainaged asset between MP 85/6 to 85/8 outside Bellevue SB and all connecting pipes as very small gullies T/L will be needed
#  replace gully cover and frame & .5m2 tarmac 100mm deep tm for 42445189 is included on this job
# Replace existing gully and frame with x1 new D400 (frame size: 550x490mm, gully top size: 510x460mm), bedded on PY4 resin, making good any brickwork required. see attachments. (Note: existing gully is currently seized shut)
# Crew are to replace 1 x D400 Side entry gully cover and frame. Crew are to ensure cover and frame are flush with the footpath.  Two way traffic lights closure required.
# IN: Drainage Systems - GULLY LID MISSING  (Enquiry 11710004) Please replace with new gully and frame which are missing. (DR: Drainage Collapsed)
# LE. Relevel side entry gully cover and frame, clear chamber (DR: Loose/Rocking Cover)
# To replace like for like Gully grate that is damaged. To also ensure Gully is emptied and running freely (MI: Other (Add Description))
# 1x new manhole lid to be provided 600x600 (MI: Other (Add Description))
# Please supply and fit new gully lid and frame to replace existing seized and end of life gully (RM: Wear)
# To un-seize Gully lid reported via custodian form.To also ensure all works on Cyclic Maintenance missed due to defect are carried out and completed. (MI: Other (Add Description))
# To un-seize Gully lid reported via custodian form.To also ensure all works on Cyclic Maintenance missed due to defect are carried out and completed.  (MI: Other (Add Description))
# To un-seize Gully lid reported via custodian form.To also ensure all works on Cyclic Maintenance missed due to defect are carried out and completed.  (MI: Other (Add Description))
# To un-seize Gully lid reported via custodian form.To also ensure all works on Cyclic Maintenance missed due to defect are carried out and completed.  (MI: Other (Add Description))
# To un-seize Gully lid reported via custodian form.To also ensure all works on Cyclic Maintenance missed due to defect are carried out and completed.  (MI: Other (Add Description))
# reset/renew 2 gully tops (DR: Loose/Rocking Cover)
# LE. Replace gully grate and frame (DR: Grating/Cover Missing)
# LE. Replace gully grate and frame (DR: Grating/Cover Missing)
# To repair sunken Gully and replace lost material around grate (11714934) (MI: Other (Add Description))
# Replace damaged manhole cover 600x600 square. (MI: Other (Add Description))
# RE. Replace gully grate (DR: Grating/Cover Missing)
# LE. Replace cover to side entry gully (DR: Grating/Cover Missing)
# CR Please reset or replace inspection cover IN: Drainage Systems - Centre res gully/manhole damaged  (Enquiry 11716779) (DR: Grating/Cover Missing)
# Replace missing gully cover and frame (DR: Grating/Cover Missing)
# VG. Replace gully trate and frame (DR: Grating/Cover Missing)
# Replace missing beanie block access lid. (MI: Other (Add Description))
# Please supply and fit new gully lid and frame and patch approx 1m x 4m x 40mm (DR: Drainage Collapsed)
# LE. Replace gully grate and frame, clean out leaves (DR: Grating/Cover Missing)
# Please replace gully top which is damaged and broken (PV: Alignment irregular)
# Please reset gully and frame which has sunk (PV: Alignment irregular)
# Please replace or reset sunken gully and patch round. (PV: Alignment irregular)
# Dropped gully. Please patch approximately 1.5m x 1m and reset Gully top to correct height (DR: Chamber/benching/pot defec)
# To investigate / Survey Drainage Issues under closure, see attached specification for requirements as NH Drainage Team. (MI: Other (Add Description))
# Pls replace lost material around 2 gullies on Stanwick Roundabout (DR: Drainage Collapsed)
# The underground pipe between the gully and the catch pit is broken / collapsed .Please dig down and replace the collapsed pipe/gully connection. (DR: Drainage Collapsed)
# Please remove all mud from the gully (Drainage Defect)
# Pls replace lost material around 2 gullies in centre res (Drainage Defect)
# LE. Relevel side entry gully grate and frame (Drainage Defect)
# Pls employ gully pot of soil (Drainage Defect)
# Please clear drainage beannie blocks at bottom of slip next to area to be resurfaced (Drainage Defect)
# Please replace with new gully and frame (Drainage Defect)
# Please supply and fit new gully lid and frame and make good surface around (Drainage Defect)
# LE. Replace broken gully grate (Drainage Defect)
# Please supply and fit new gully lid and frame and make good surrounding surface (Drainage Defect)
# Between MP190/0 - 190/5 please remove all growth from V channel and gullies to allow free flow of water, thats building up.(Drainage Defect)
# LE. Replace gully chamber, grate and frame. (Drainage Defect) - to be done overnight on callout?
# Please clear all artirial gully fronts to ensure that they are working. Also sweep and clean the weeds from the kerb line (Drainage Defect)
# HS Please clear drainage with discharging inspection cover (Drainage Defect)
# Please reset this gully which has sunken and set it to the right level (Drainage Defect)
# Please infill/make good, permanent patch surface around gully (Drainage Defect)
# A14 eastbound 52/5+50 in ox bow lay-by nearside  Gully top collapsing  Break out gully top and rebuild to support frame Make good surrounding pavement   Traffic management required lay-by closure (DR: Drainage Collapsed)
# A14 eastbound 52/6+20 in ox bow lay-by nearside  Gully top collapsing  Break out gully top and rebuild to support frame Make good surrounding pavement   Traffic management required lay-by closure (DR: Drainage Collapsed)
# A14 eastbound 52/6+60 in exit from ox bow lay-by nearside  Gully top collapsing and broken  Break out gully top and rebuild to support frame replace with new gully top Make good surrounding pavement   Traffic management required lay-by closure (DR: Drainage Collapsed)
# A14 eastbound oxbow lay-by 59/3  Kerb gully has collapsed   Break our gully and reconstruct foundations  Traffic management not required as in lay-by (DR: Drainage Collapsed)
# Gully is loose and rocking. Works required: break out all previous viafix repair. Clean up brick bed and lay new cement to place gully back on top of. Re instate around gully with tarmac so it is flush.  TM required: Traffic light system with safe working zone as it is two lane. (DR: Loose/Rocking Cover)
# Gully grille has cracked and started to fall into the chamber. This is currently coned off.  Works required - A new d400 550mm x 500mm gully frame and cover is required. This will require saw cutting the cement road surface around the existing gully, to be able to cleanly break it out. Please install new frame and gully onto a fresh bed of mortar and make good the surround with suitable road reinstatement material.  This requires no TM, other than coning off a works area. (DR: Grating/Cover Missing)
# A14 eastbound entry slip jcn 20  Gully half way down slip is collapsing (3rd gully down from roundabout)  Break out gully top and reseat, make good surrounding pavement to level  Traffic management required- traffic lights or stop/go boards - 2 wsy slip (DR: Drainage Collapsed)
# Missing gully lid Make safe with cones as open hole currently  A421 eastbound 7/8 oxbow lay-by  First gully in beanie kerb    Lane 1 closure/lay-by closure advised (DR: Grating/Cover Missing)
# Large heavy wide crane knocked gully cover off. (DR: Grating/Cover Missing)
# Instruction - Raise and reset Gully frame in concrete then top up the surround with via fix. TM required will be full closure of lay-by. (SG:Physical condition of frame)
# Fix now- cleared gully top (DR: Free flow impeded)
# Fix now- cleared gully top (DR: Free flow impeded)
# A14 Westbound 57/0+50 Collapsed gully in layby  (has been made safe with sandbags and Viafix) Remove all temporary make safe measures and install new D400 gully by rebuilding chamber if necessary. Make good surrounding pavement to level with existing traffic management required - local coning / layby closure (DR: Drainage Collapsed)
# Damaged/Missing arterial side entry gully cover and frame 530mm x 380mm . TM required back to back static Lane 2 lane closures (DR: Grating/Cover Missing)
# Fit new 450mm x 600mm gully cover and frame and reinstate around as required. TM will be 3 way traffic signal closure (DR: Drainage Collapsed)
# Instruction: reset gully & repair pavement around gully Location: A5 NB @ Sheeplane Rbt, L1 curb line/LHWT, approx 63/4+40A, last gully before give way TM: 4 way lights required (Pavement Defect)
# Gully clearance, at capacity   Location - Singles, Sheeps Lane - Little Brickhill 63/5-63/9 Road - A5  Direction - Northbound  Junction- Sheeps Ln - Brickhill Marker post start/end- 63/5-63/9 Verge/Nearside  Number of gullies - 20  TM Required - 2 way traffic lights (Drainage Defect)
# Dropped gully  A421 wb 26/2+85 in lay-by  1x gully has dropped  Dig out and remove gully top and build up chamber if required then reset gully top  Tm Required: lane 1 + lay-by closed  A421 wb 26/2+85 in lay-by (Drainage Defect)
# Instruction: Replacement of 1 x gully top Location: A5 NB Singles 61/4 +20A, Heath and Reach to Sheeplane, L1, N/S  Road: A5 NB Singles Direction: NB Junction: Heath and Reach to Sheeplane Components required: 1 x Gully top TM Required: 2 way t/lights (Drainage Defect)
# Drainage Defect
# 500mm x300mm in line gully is damaged and in need of replacement  Work will be to remove old gully from within the kerb replace with new splay Edge gully and reinstated new frame and cover and surrounding pavement.  TM will be to close the entry to the layby for safe working zone  but leave the exit open. (Drainage Defect)
# A14 westbound 50/4 in Oxbow layby (10m past ERT) Gully has collapsed and been made safe Break out remains of gully and remove sandbags etc. from hole Install new 450mm x 450mm gully and frame, rebuild blockwork as required  Make good surrounding pavement to level with existing Traffic management required - local coning only - located in parking area of layby (Drainage Defect)
# Clear gully top (Drainage Defect)
# Clear gully top (Drainage Defect)
# Clear gully top (Drainage Defect)
# Clear gully top (Drainage Defect)
# Clear gully top (Drainage Defect)
# A14 westbound 61/1 in Emergency layby  (Enquiry - 16810495)  Gully top has gone missing Break out remains of old frame for correct disposal / recycling.  Install new Saint-Gobain AQUA-MAX D400 (Kerb Hinged grate) - 450 x 450mm frame and cover. Make good surrounding pavement to level Traffic management required - layby closure (Drainage Defect)
# A14 westbound 52/7+60 in layby  (Enquiry - 16810544) W3W - files.teaching.chairing.   Gully top has gone missing Break out remains of old frame for correct disposal / recycling. Install new Saint-Gobain AQUA-MAX D400 (Kerb Hinged grate) - 450 x 450mm frame and cover.  Make good surrounding pavement to level Traffic management required - layby closure (Drainage Defect)
# Gully lid cracked. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# Gully lid cracked and collapsing. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# Gully with missing cover previously made safe.  Pre score 9. Post score 9. (DR: Grating/Cover Missing)
# A gully had collapsed on one corner and requires ecrew to make safe under a police block, pre score 12 post 9. (DR: Drainage Collapsed)
# Collapsing gully. Previous temporary repairs failed. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# Gully lid cracked and collapsing. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# 1x collapsed gully in lane one (DR: Drainage Collapsed)
# Gully collapsing, surrounding surface breaking up. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# Gully cover cracked. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# Temporary repairs to collapsing gully failed. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# Temporary repairs to collapsing gully failed. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# Temporary repairs to collapsing gully failed. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# 1 x sunken gully which had been topped up but tarmac broken away requires Ecru to attend to make safe (top up) defect pre score of 12 and post score of 12 (DR: Drainage Collapsed)
# 1 x sunken with difference in level of carriageway needs resetting defect pre score of 12 and post score of 12 requires Ecru to attend to make safe (DR: Drainage Collapsed)
# Missing kerb gully lid on nearside verge (DR: Drainage Collapsed)
# Missing kerb gully lid nearside verge (DR: Drainage Collapsed)
# Broken kerb gully nearside verge (DR: Drainage Collapsed)
# Temporary repair to collapsed gully failing. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# Collapsed gully with missing cover requires permanent repair  Pre score 9. Post score 9. (DR: Drainage Collapsed)
# One half of gully lid broken nearside kerb (DR: Drainage Collapsed)
# Gully collapsing, surrounding surface breaking up. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# Temporary repairs to collapsing gully failing.  Pre score 12. Post score 12. (DR: Drainage Collapsed)
# Temporary repair to collapsed gully failing. Pre score 12. Post score 12   (Enquiry 19007262) (DR: Drainage Collapsed)
# Temporary repairs to missing gully lid failing. Pre score 12. Post score 12. (DR: Drainage Collapsed)
# Collapsed gully in lane 1 on main carriageway, ECRU to make safe, defect  score 16. A residual defect will be raised for a permanent repair. (DR: Drainage Collapsed)
# 1 xgullframe and lid  broken and fallen in to chamber. Defect score pre 12 post 12 (DR: Drainage Collapsed)
# 1x gully lid collapsed in lane one nearside will need lane one to make safe unfortunately unable go take photos (Drainage Defect)
# Gully loose and rocking, surrounding surface breaking up.  Requires making safe. Pre score 12. Post score 12. (Drainage Defect)
# Sunk and rocking gully, requires making safe, pre score 12. (Drainage Defect)
# Gully collapsing (Drainage Defect)
# M5 southbound jct 1 to 2 (Drainage Defect)
# 1x pothole (refill) around previous collapsed gully nearside in lane one (Drainage Defect)
# M5 southbound jct 1 to 2 (Drainage Defect)
# M5 southbound jct 1 to 2 (Drainage Defect)
# Broken gully nearside kerb line (Drainage Defect)
# Sunken pothole requires top up of instamac for temp repair while awaiting full gully replacement (Drainage Defect)
# Temporary fill in a gully has dropped and requires topping. (Drainage Defect)
# ZRT Gully top and apron on hard shoulder to be scraped off as these are covered over with mud. No traffic management required. (Drainage Defect)
# Gully has collapsed and requires ZRT to make safe, pre score 15. (Drainage Defect)
# Gully opposite childswickham junction has a broken lid, 450mmx450mm needs replacing. Pre score 16 post score 16 Rolling block required (Drainage Defect)
# Gully collapsing, gully needs temp repair  Pre score 16 post score 16 (Drainage Defect)
# X1 pothole around gully. Gully lid moved and will require filling in. (Drainage Defect)
# Sunked/collapsed gully cover requires covering over until permanent repair can be made (Drainage Defect)
# Collapsing gully need recapping over with cold lay to make safe (Drainage Defect)
# Pothole around gully, gully breaking out Pre score 16 post score 16 (Drainage Defect)
# Can M&R attend the address and lay sandbags as a make safe measure please. They were previously installed but customer has contacted to say they have been removed - DR: Drainage Systems Placed on high priority due to concerns for the customer and his wifes well being.  (Enquiry 14577626)
# Collapsed gully in lay by needs make safe and raising for permanent repair (Drainage Defect)
# Crew are to replace the D400 Side entry gully cover with a D400 Gully grating (600mm x 600mm).  Crew are to lower the surrounding kerb as necessary and put in a concrete apron around the gully grating.  Crew are to remove the cone from site, once the repair is complete.
# Crew are to replace 1 x D400 Gully grating and frame.  Traffic management suppled through other opportunities.
# Crew are to replace the D400 Side entry gully cover with a D400 Gully grating.  Crew are to lower the surrounding kerb as necessary and put in a concrete apron around the gully grating.
# patching as patch no 4 on the attached schedule
# Broken gully lid will need to be made safe , remove broken lid and fill with sandbags and cover top with instarmac to make safe until a permanent repair can be arranged (Drainage Defect)
#  (Enquiry 12121430)Please provide flood boards in advance of the layby,  Another job will be raised to carry out further investigation
# Please clear 15 covered gully tops (Drainage Defect)
# Please clear 2 side entry piped inlets and cut 2 grips (Drainage Defect)
# please attend Full closure on 10/11/22 with Vactor unit to resolve any gully clearance issues not being cleared through standard cyclic operations
# Please clear 7 covered gully tops (Drainage Defect)
# Water encorouching into lane 1. RINGWAY to attend and clear gullies leaving H/S & live lane clear of water.
# Pothole around gully. 600mm x 600mm x 140mm deep. Just after sliproad.  TM will be needed during repair.  Temp repair needed (Drainage Defect)
#  (Enquiry 12122430) Replace gully cover & frame & replace surround min 300mm away from frame on all sides, saw cut to all sides required
# Crew are to replace 1x D400 Manhole cover. (600mm x 600mm)  Crew are to lower the surrounding kerb as necessary and put in a concrete apron around the Manhole cover.  Crew are to remove the cone from site, once the repair is complete.
# Using MLC's already booked for training pleaseclear all gully and catch pit tops in cen res between 259/7 and 260/0 and use sweeper to clear front of beanie kerbs between 260/1 and 261/1
# PERMANENT REPAIR to reset 3 x sunken gullies,  level up to c/w level    Left of Lane 1 - against kerb.  .  (Pavement Defect)

# %% [markdown]
# ### I am happy that none of the above have the failure mode of gully full

# %% [markdown]
# ### Investigate Covered Failure Modes
# <br> 1. If an event has a covered key word count greater than 2 then we will be pretty confident that the gully was covered
# <br> 2. The FIX NOW priority indicates that an inspector swept the gully or put the lid back on - ie they don't have the ability to empty a full drain.
# <br> 3. If there is a FIX NOW priority and one or more key words then we can confidently classify it as a covered failure

# %%
text_analysis_quality[(text_analysis_quality["covered_key_word_count"] > 0)&(text_analysis_quality["ParameterValueID"]!="7510")&(text_analysis_quality["PriorityID"]=='FNOW')]
# Out:
#            JobID        CentralAssetID                EntryDateTime  \
# 23      12007341         A12GU00006623  2022-09-21 13:59:57.0000000
# 24      12007659         A12GU00023573  2022-10-10 10:14:02.0000000
# 25      12007661         A12GU00023583  2022-10-10 10:24:59.0000000
# 28      12008437         A12GU00027932  2022-12-12 13:38:20.0000000
# 29      12008439         A12GU00027932  2022-12-12 13:45:39.0000000
# ...          ...                   ...                          ...
# 533629  54077389        A21DRGU/031447  2023-02-01 09:01:19.0000000
# 533630  54077447        A21DRGU/007340  2023-02-03 09:39:06.0000000
# 533633  54078123        A21DRGU/002307  2023-02-27 09:34:35.0000000
# 534363  54273983        A21DRGU/004804  2023-04-13 08:25:23.0000000
# 566323  58149402  DR/HEA10/DRGU/034212  2023-01-15 08:59:55.0000000
#
#                                                     Notes  FloodHotspot  \
# 23      Gully top blocked. Cleared with fix now (Drain...             0
# 24      Partially blocked gully top. Cleared with fix ...             0
# 25      Partially blocked gully top. Fix now (Drainage...             0
# 28              Gully covered in debris (Drainage Defect)             0
# 29                   Clear top of gully (Drainage Defect)             0
# ...                                                   ...           ...
# 533629  Cleared debris off x7 gully lids (Drainage Def...             1
# 533630  X2 gully lids covered with silt and rubbish (D...             1
# 533633      X6 gullys covered with silt (Drainage Defect)             0
# 534363               2x gullies cleared (Drainage Defect)             0
# 566323  Flooding  Gully cover cleared of debris (Drain...             0
#
#         JobStatusName PriorityID        PriorityName  \
# 23      Work Complete       FNOW  Fix Now - Internal
# 24      Work Complete       FNOW  Fix Now - Internal
# 25      Work Complete       FNOW  Fix Now - Internal
# 28      Work Complete       FNOW  Fix Now - Internal
# 29      Work Complete       FNOW  Fix Now - Internal
# ...               ...        ...                 ...
# 533629  Work Complete       FNOW  Fix Now - Internal
# 533630  Work Complete       FNOW  Fix Now - Internal
# 533633  Work Complete       FNOW  Fix Now - Internal
# 534363  Work Complete       FNOW  Fix Now - Internal
# 566323  Work Complete       FNOW  Fix Now - Internal
#
#            ActualCompletionDateTime RouteID ParameterTypeID ParameterValueID  \
# 23      2022-09-21 14:00:31.0000000    NO87            %FUL             CLEA
# 24      2022-10-10 10:14:47.0000000    NO09            %FUL             CLEA
# 25      2022-10-10 10:25:25.0000000    NO09            %FUL             CLEA
# 28      2022-12-12 14:24:07.0000000    NO89            %FUL               NK
# 29      2022-12-12 13:46:48.0000000    NO89            %FUL             CLEA
# ...                             ...     ...             ...              ...
# 533629  2023-02-01 09:01:39.0000000    3001            %FUL             0-25
# 533630  2023-02-03 09:39:55.0000000    3803            %FUL             0-25
# 533633  2023-02-27 09:35:56.0000000    3803            %FUL             2550
# 534363  2023-04-13 08:25:46.0000000    3803            %FUL             0-25
# 566323  2023-01-15 09:02:10.0000000    M111            %FUL             0-25
#
#                ExtractTimestamp  Failure_or_Maintenance  \
# 23      2023-04-21 10:59:09.627                       1
# 24      2023-04-21 10:59:09.627                       1
# 25      2023-04-21 10:59:09.627                       1
# 28      2023-04-21 10:59:09.627                       1
# 29      2023-04-21 10:59:09.627                       1
# ...                         ...                     ...
# 533629  2023-04-21 10:59:09.627                       1
# 533630  2023-04-21 10:59:09.627                       1
# 533633  2023-04-21 10:59:09.627                       1
# 534363  2023-04-21 10:59:09.627                       1
# 566323  2023-04-21 10:59:09.627                       1
#
#         covered_key_word_count  full_key_word_count  broken_key_word_count  \
# 23                           2                    2                      0
# 24                           1                    2                      0
# 25                           1                    1                      0
# 28                           2                    1                      0
# 29                           1                    0                      0
# ...                        ...                  ...                    ...
# 533629                       2                    2                      0
# 533630                       1                    1                      0
# 533633                       1                    1                      0
# 534363                       2                    0                      0
# 566323                       3                    2                      0
#
#         Full_or_Not
# 23                0
# 24                0
# 25                0
# 28                0
# 29                0
# ...             ...
# 533629            0
# 533630            0
# 533633            0
# 534363            0
# 566323            0
#
# [852 rows x 18 columns]

# %% [markdown]
# ### We can use FixNow to classify covered drainage where %ful is clear or < 7510 --- Pick up here - incorporate below

# %% [markdown]
# # End of Analysis - Implementation

# %% [markdown]
# ## Create Data Pipeline

# %%
import pandas as pd

# %%
interventions = pd.read_csv("../project_data/interventions_dataset.csv",names=[
"JobID"
,"CentralAssetID"
,"SiteID"
,"PlotNo"
,"AssetTypeID"
,"LogNo"
,"EntryDateTime"
,"Notes"
,"JobTypeID"
,"JobTypeCode"
,"JobTypeName"
,"JobStatusID"
,"FloodHotspot"
,"JobStatusName"
,"PriorityID"
,"PriorityName"
,"ActualStartingDateTime"
,"ActualCompletionDateTime"
,"ActualCompletionYearMonth"
,"RouteID"
,"ParameterTypeID"
,"ParameterValueID"
,"IsDeletedFlag"
,"IsCurrentFlag"
,"ValidFromDateTime"
,"ValidToDateTime"
,"InsertedDateTime"
,"JobItemID"
,"SorItemID"
,"ExtractTimestamp"],header=None,index_col=False)
def formatting_failure_vs_maintenance(string): 
    if string.find("B") != -1:
        return 1
    else:
        return 0

interventions["Failure_or_Maintenance"] = interventions["JobTypeCode"].apply(formatting_failure_vs_maintenance)

def create_prefix(siteid):
    return siteid[0:4]

interventions["prefix"] = interventions["SiteID"].apply(create_prefix)
interventions = interventions[(interventions["IsCurrentFlag"]==1)&(interventions["IsDeletedFlag"]==0)]
interventions = interventions.groupby(['JobID', 'CentralAssetID','EntryDateTime','Notes','FloodHotspot', 'JobStatusName', 'PriorityID',
       'PriorityName','ActualCompletionDateTime', 'RouteID', 'ParameterTypeID',
       'ParameterValueID', 'ExtractTimestamp', 'Failure_or_Maintenance','prefix'],as_index=False)["ValidFromDateTime"].max()
interventions.drop(columns="ValidFromDateTime",inplace=True)
# Out:
# /home/tgraham/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3106: DtypeWarning: Columns (28) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
reactive = interventions[interventions["Failure_or_Maintenance"]==1]
key_words_covered = ["covered","leaves","Covered","Leaves","Clear","clear","CLEAR","cleared","CLEARED","clearing","cleaning","top blocked","Cleaning","mouth","mouths",
                     "debris","Debris","swept","Sweep","SWEPT","SWEEP","sweep","uncover","Uncover","grate","Obstruction","obstructed","detritus","Detritus","DETRITUS",
                     "Free flow impeded","Fix now","leaf","leaves","Fall","fall","Clear blocked gully grating","clear covers","Clear gully cover","Blocked gully tops",
                     "Grass growing","Drainage Defect","mud","clean","free flow"]

key_words_full = ["empty","Empty","emptying","Emptying","gully cleaning","cleansing","cleaning out","jet","Jet","jetted","Jetted","Jetting","sucking","Sucking","sucker","SUCKER",
                 "sucked","Sucked","Suck","SUCK","suck","vac","blocked","Blocked","blockage","Blockage","unblock","Unblock","blocking","Blockage","Silt","silted","silt",
                  "Clean out gully","Flooding","flooding","filled","Soil", "Cleared","debris","Debris","clearing","detritus","cleaning","CLEARING","FLOOD","BLOCKED",
                  "Standing water","standing","Please clear 8 gullies","full of mud"]

key_words_broken = ["collapsing","sunken","Collapsing","Sunken","Reset","reset","re-setting","Broken","broken","replace",
                    "Replace","collapsed","Collapsed","COLLAPSED","pothole","Pothole","POTHOLE","RESET","fit","Fit","FIT",
                   "Adjust","ADJUST","adjust","repair","Repair","missing","Missing","replacing","Replace","REPLACE","REPLACING",
                   "cracked","Cracked","CRACKED","Sandbag","sandbag","Sandbags","SANDBAG","breaking","Breaking","dislodged","Dislodged","misaligned",
                   "Misaligned","degraded","Degraded","frame","Frame","Rattling","rattling","REPAIR","setting","Setting","re-set","Raise",
                    "Hole","hole","patch","Patch","damage","Damage","rocking","Rocking","sunk","Sunk","SUNK","CCTV","cctv","reseating","collapse",
                   "Reinstate","level with","Level with","unseize","seize","sieze","Unseize","Seize","broken","New gully lid required","no lid","No lid",
                    "lid open","Lid popped out","realingning","stick out","dislodge","Re-set"]

reactive["covered_key_word_count"] = 0
reactive["full_key_word_count"] = 0
reactive["broken_key_word_count"] = 0 
count = 0
for item in reactive["Notes"]:
    count += 1
    count_of_covered_key_words=0
    for key_word in key_words_covered:
        if item.find(key_word) != -1:
            count_of_covered_key_words += 1
    reactive.loc[reactive["Notes"] == item, "covered_key_word_count"] = count_of_covered_key_words

    count_of_full_key_words=0
    for key_word in key_words_full:
        if item.find(key_word) != -1:
            count_of_full_key_words += 1
    reactive.loc[reactive["Notes"] == item, "full_key_word_count"] = count_of_full_key_words
    
    count_of_broken_key_words=0
    for key_word in key_words_broken:
        if item.find(key_word) != -1:
            count_of_broken_key_words += 1
    reactive.loc[reactive["Notes"] == item, "broken_key_word_count"] = count_of_broken_key_words

    if count % 1000 == 0 :
        print(count)
# Out:
# /tmp/ipykernel_150245/3702950441.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reactive["covered_key_word_count"] = 0
# /tmp/ipykernel_150245/3702950441.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reactive["full_key_word_count"] = 0
# /tmp/ipykernel_150245/3702950441.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reactive["broken_key_word_count"] = 0
# /home/tgraham/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)
# 1000
# 2000
# 3000
# 4000

# %% [markdown]
# ## Create Validation Columns

# %%
reactive["full_failure"] = reactive["full_key_word_count"]
reactive["covered_failure"] = reactive["covered_key_word_count"]
reactive["broken_failure"] = reactive["broken_key_word_count"]
# Out:
# /tmp/ipykernel_150245/3847258014.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reactive["full_failure"] = reactive["full_key_word_count"]
# /tmp/ipykernel_150245/3847258014.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reactive["covered_failure"] = reactive["covered_key_word_count"]
# /tmp/ipykernel_150245/3847258014.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reactive["broken_failure"] = reactive["broken_key_word_count"]

# %% [markdown]
# ## Apply validation rules

# %%
for index, row in reactive.iterrows():
    # When we have FNOW data we need to classify if it is covered or broken. It cannot be full.
    if row["covered_key_word_count"] > 0 and row["PriorityID"]=='FNOW' and row["full_key_word_count"] > 0:
        reactive.loc[index, "full_failure"] = 0
    
    # This is to cover the blocked issue, blocked is a full keyword but in the case of Fix Now it acts as a covered key word
    if row["covered_key_word_count"] == 0 and row["PriorityID"]=='FNOW' and row["full_key_word_count"] > 0:
        reactive.loc[index, "covered_failure"] = 1 
        
    # This classifys broken fixnow jobs    
    if row["PriorityID"]=='FNOW' and row["broken_key_word_count"] > 0:
        reactive.loc[index, "broken_failure"] = 1
    
    # If we have missing data and we have confidence that the job is classifying full then we can assume it is between 75-100% full
    if row["full_key_word_count"] > 1 and row["PriorityID"]!='FNOW' and row["ParameterValueID"] == 'NK':
        reactive.loc[index,"ParameterValueID"] = '7510'
    
    # This is to change classifications from full to covered if the % full is not high. Similar words can be used for each 
    if row["full_key_word_count"] > 0 and row["ParameterValueID"] not in ('7510','NK'):
        reactive.loc[index, "full_failure"] = 0
        reactive.loc[index, "covered_failure"] = 1

# %%
def adjust_word_count_to_binary(x):
    if x > 1: 
        return 1 
    else:
        return x 
    
reactive["covered_failure"] = reactive["covered_failure"].apply(adjust_word_count_to_binary)
reactive["full_failure"] = reactive["full_failure"].apply(adjust_word_count_to_binary)
reactive["broken_failure"] = reactive["broken_failure"].apply(adjust_word_count_to_binary)
# Out:
# /tmp/ipykernel_150245/1046574324.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reactive["covered_failure"] = reactive["covered_failure"].apply(adjust_word_count_to_binary)
# /tmp/ipykernel_150245/1046574324.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reactive["full_failure"] = reactive["full_failure"].apply(adjust_word_count_to_binary)
# /tmp/ipykernel_150245/1046574324.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   reactive["broken_failure"] = reactive["broken_failure"].apply(adjust_word_count_to_binary)

# %%
reactive.drop(columns=["covered_key_word_count","full_key_word_count","broken_key_word_count"],inplace=True)
# Out:
# /home/tgraham/.local/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
cyclic = interventions[interventions["Failure_or_Maintenance"]==0]
cyclic["full_failure"] = 0
cyclic["covered_failure"] = 0
cyclic["broken_failure"] = 0
# Out:
# /tmp/ipykernel_150245/2830057744.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cyclic["full_failure"] = 0
# /tmp/ipykernel_150245/2830057744.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cyclic["covered_failure"] = 0
# /tmp/ipykernel_150245/2830057744.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cyclic["broken_failure"] = 0

# %%
final_interventions = pd.concat([reactive,cyclic])

# %% [markdown]
# ## Sense test below to randomly check the quality of the final classification

# %%
final_interventions[final_interventions["Failure_or_Maintenance"]==1].sample(n=25)
# Out:
#            JobID        CentralAssetID                EntryDateTime  \
# 97151   41413530        A14DRGU/007296  2020-08-18 23:13:50.0000000
# 6293    40437437    DRGU/A04/P00009734  2022-05-20 10:41:46.0000000
# 432943  46519180  00000000006800003367  2022-03-24 12:09:44.0000000
# 97248   41727687        A07DRGU/016466  2019-12-12 12:27:35.0000000
# 447705  49144417      DR/A09/GU/116186  2022-03-09 07:43:12.0000000
# 433441  46540055        A68DRGU/020284  2022-05-03 11:30:01.0000000
# 97159   41414195        A14DRGU/002170  2020-09-25 09:25:23.0000000
# 448222  49152335              19017993  2022-08-18 07:20:40.0000000
# 292116  43115343        A07DRGU/016470  2020-11-05 12:05:00.0000000
# 448388  49159564      DR/A09/GU/049524  2022-11-04 10:26:06.0000000
# 447283  49133220      DR/A09/GU/072617  2021-08-03 08:37:51.0000000
# 435506  46564555        A68DRGU/000045  2022-10-28 15:17:46.0000000
# 447746  49147581              19016036  2022-05-25 10:06:49.0000000
# 7064    40442221    DRGU/A04/P00004284  2022-06-14 13:10:41.0000000
# 292628  43372237        A07DRGU/067520  2023-01-25 11:57:47.0000000
# 938     40409533    DRGU/A04/P00007076  2021-10-28 13:29:00.0000000
# 292030  42901035           DRGU/007192  2022-12-22 08:45:34.0000000
# 447099  49119624      DR/A09/GU/005118  2021-01-25 15:26:02.0000000
# 245147  42464749        A21DRGU/070819  2021-12-28 09:37:44.0000000
# 447560  49143790              19010761  2022-03-02 09:38:18.0000000
# 448264  49155347      DR/A09/GU/002170  2022-09-26 11:08:47.0000000
# 292459  43357375        A07DRGU/032732  2022-05-05 12:58:38.0000000
# 435183  46562477        A68DRGU/051393  2022-10-12 11:25:00.0000000
# 435038  46558594        A68DRGU/029354  2022-08-11 13:18:21.0000000
# 202171  42328645        A21DRGU/068891  2021-03-26 09:15:45.0000000
#
#                                                     Notes  FloodHotspot  \
# 97151   Gully lid has came loose and misaligned. Reali...             0
# 6293    Blocked gully  L=3 C=3 T=9 Unblock gully and r...             0
# 432943  Fix now- clear catch pit top (DR: Free flow im...             0
# 97248   Unblock artirial gully and clear silt (DR: Blo...             1
# 447705             Gully requires emptying (DR: Blockage)             0
# 433441  Blocked gully pot needs to be dug out and aris...             0
# 97159   Clear blocked channel of vegetation (DR:Impede...             0
# 448222  Collapsed gully  Pre score 16 post score 16 (D...             0
# 292116  Clear debris from front of artirial gully (DR:...             1
# 448388  Gully top needs clearing off VERGE (Drainage D...             1
# 447283  Blocked gully requires emptying hardshoulder p...             1
# 435506  FLOOD HOT SPOT - Dig out gully & jet to outfal...             1
# 447746  Gully loose and rocking, surrounding surface b...             0
# 7064    Bridge Deck Drainage Unit Gully blocked with e...             0
# 292628  Please replace gully top which is broken (Drai...             0
# 938     Gully cover now blocked after recent rainfall ...             0
# 292030  Manhole cover requires investigation to unbloc...             0
# 447099  Gully obstructed by detritus. Cleared. Pre sco...             0
# 245147  8 gullies cleared. Blocked from heavy rain (DR...             0
# 447560  1x gully in lane one nearside blocked (DR: Blo...             0
# 448264  Blocked gully  Pre score 12 post score 12 Gull...             0
# 292459  RE. Replace rattling gully grate and frame (Dr...             0
# 435183                                    Drainage Defect             1
# 435038  Blocked gully pot needs to be dug out and aris...             0
# 202171                       Blocked gully (DR: Blockage)             1
#
#                        JobStatusName PriorityID            PriorityName  \
# 97151                  Work Complete       FNOW      Fix Now - Internal
# 6293                   Work Complete       28DY                 28 days
# 432943                 Work Complete       FNOW      Fix Now - Internal
# 97248                     Job Closed       FNOW      Fix Now - Internal
# 447705                    Job Closed       PAD1  PAD: Non Safety - High
# 433441                 Work Complete       28DY                 28 days
# 97159                  Work Complete       FNOW      Fix Now - Internal
# 448222                    Job Closed       24HC       24 Hours - Commit
# 292116                    Job Closed       FNOW      Fix Now - Internal
# 448388                 Work Complete       28DY                 28 days
# 447283                    Job Closed       PAD1  PAD: Non Safety - High
# 435506                 Work Complete       3MON                3 Months
# 447746        Remedial Work Complete       24HC       24 Hours - Commit
# 7064                   Work Complete       28DY                 28 days
# 292628  Post Compl Inspection Passed       28DY                 28 days
# 938                    Work Complete       24HC       24 Hours - Commit
# 292030                 Work Complete       2MON                2 Months
# 447099                 Work Complete       FNOW      Fix Now - Internal
# 245147                 Work Complete       FNOW      Fix Now - Internal
# 447560                    Job Closed       PAD1  PAD: Non Safety - High
# 448264                    Job Closed       28DY                 28 days
# 292459  Post Compl Inspection Passed       28DY                 28 days
# 435183                 Work Complete       FNOW      Fix Now - Internal
# 435038                 Work Complete       28DY                 28 days
# 202171                 Work Complete       FNOW      Fix Now - Internal
#
#            ActualCompletionDateTime RouteID ParameterTypeID ParameterValueID  \
# 97151   2020-08-18 23:13:48.0000000    NE33            %FUL               NK
# 6293    2022-06-20 14:20:49.0000000    4270            %FUL             7510
# 432943  2022-03-24 12:09:54.0000000    E066            %FUL             CLEA
# 97248   2019-12-12 12:27:35.0000000     R24            %FUL               NK
# 447705  2022-03-09 07:42:00.0000000    A941            %FUL             7510
# 433441  2022-05-18 02:21:39.0000000    E041            %FUL             5075
# 97159   2020-09-25 09:26:34.0000000    NE24            %FUL               NK
# 448222  2022-08-18 11:39:07.0000000    A908            %FUL             0-25
# 292116  2020-11-05 12:04:50.0000000     R24            %FUL               NK
# 448388  2023-02-08 13:09:29.0000000    A912            %FUL               NK
# 447283  2022-01-19 06:30:57.0000000    A912            %FUL             7510
# 435506  2022-12-07 02:48:22.0000000    E038            %FUL             5075
# 447746  2022-05-26 03:28:49.0000000    A938            %FUL             7510
# 7064    2022-10-27 12:41:32.0000000    4177            %FUL             7510
# 292628  2023-02-08 23:50:28.0000000     R16            %FUL             2550
# 938     2021-10-28 16:30:00.0000000    4284            %FUL             0-25
# 292030  2023-03-03 23:17:03.0000000    1201            %FUL             0-25
# 447099  2021-01-25 15:26:30.0000000    A909            %FUL               NK
# 245147  2021-12-28 09:38:06.0000000    M506            %FUL             7510
# 447560  2022-03-16 12:16:11.0000000    A901            %FUL             7510
# 448264  2022-11-01 23:16:50.0000000    A908            %FUL             7510
# 292459  2022-05-19 10:00:00.0000000     R05            %FUL             0-25
# 435183  2022-10-12 11:26:02.0000000    E066            %FUL             0-25
# 435038  2022-08-17 01:27:37.0000000    E120            %FUL             2550
# 202171  2021-03-26 09:17:16.0000000    M506            %FUL               NK
#
#                ExtractTimestamp  Failure_or_Maintenance prefix  full_failure  \
# 97151   2023-04-21 10:59:09.627                       1   NE14             1
# 6293    2023-04-21 10:59:09.627                       1   SE04             1
# 432943  2023-04-21 10:59:09.627                       1   EA68             0
# 97248   2023-04-21 10:59:09.627                       1   MD07             0
# 447705  2023-04-21 10:59:09.627                       1   MD09             1
# 433441  2023-04-21 10:59:09.627                       1   EA68             0
# 97159   2023-04-21 10:59:09.627                       1   NE14             0
# 448222  2023-04-21 10:59:09.627                       1   MD09             0
# 292116  2023-04-21 10:59:09.627                       1   MD07             0
# 448388  2023-04-21 10:59:09.627                       1   MD09             1
# 447283  2023-04-21 10:59:09.627                       1   MD09             1
# 435506  2023-04-21 10:59:09.627                       1   EA68             0
# 447746  2023-04-21 10:59:09.627                       1   MD09             0
# 7064    2023-04-21 10:59:09.627                       1   SE04             1
# 292628  2023-04-21 10:59:09.627                       1   MD07             0
# 938     2023-04-21 10:59:09.627                       1   SE04             0
# 292030  2023-04-21 10:59:09.627                       1   NW13             0
# 447099  2023-04-21 10:59:09.627                       1   MD09             0
# 245147  2023-04-21 10:59:09.627                       1   SW21             0
# 447560  2023-04-21 10:59:09.627                       1   MD09             1
# 448264  2023-04-21 10:59:09.627                       1   MD09             1
# 292459  2023-04-21 10:59:09.627                       1   MD07             0
# 435183  2023-04-21 10:59:09.627                       1   EA68             0
# 435038  2023-04-21 10:59:09.627                       1   EA68             0
# 202171  2023-04-21 10:59:09.627                       1   SW21             1
#
#         covered_failure  broken_failure
# 97151                 1               1
# 6293                  1               0
# 432943                1               0
# 97248                 1               0
# 447705                0               0
# 433441                1               1
# 97159                 1               0
# 448222                1               1
# 292116                1               0
# 448388                1               0
# 447283                0               0
# 435506                1               0
# 447746                1               1
# 7064                  1               0
# 292628                1               1
# 938                   1               0
# 292030                1               1
# 447099                1               0
# 245147                1               0
# 447560                0               0
# 448264                1               0
# 292459                1               1
# 435183                1               0
# 435038                1               1
# 202171                1               0

# %%
final_interventions[(final_interventions["Failure_or_Maintenance"] == 1)&(final_interventions["full_failure"]==0)&(final_interventions["covered_failure"]==0)&(final_interventions["broken_failure"]==0)]
# Out:
#            JobID      CentralAssetID                EntryDateTime  \
# 200     40327391    A03PO/DRGU146928  2023-01-24 10:35:24.0000000
# 1038    40414193  DRGU/A04/P00025943  2022-03-17 09:30:58.0000000
# 1039    40414194  DRGU/A04/P00003440  2022-03-17 09:35:28.0000000
# 242883  42458899      A21DRGU/019853  2021-11-17 13:22:10.0000000
# 292337  43231865      A07DRGU/027042  2021-09-23 15:21:30.0000000
# 292406  43239101      A07DRGU/011701  2022-01-14 11:19:23.0000000
# 533535  54074191      A21DRGU/004828  2022-10-21 11:18:34.0000000
# 533548  54074671      A21DRGU/128978  2022-11-08 10:06:13.0000000
#
#                                                     Notes  FloodHotspot  \
# 200     TRAFFIC MANAGEMENT ORDER TO DELIVER 2 X CLOSUR...             1
# 1038                Scd 'D' for IPV only for job 40412297             0
# 1039                 Scedule 'D' for IPV for job 40412470             0
# 242883  IN: Ironwork - PLESAE ATTEND AND MAKE SAFE  (E...             0
# 292337  Drainage works  Please se attachments for info...             1
# 292406  To investigate / Survey Drainage Issues under ...             1
# 533535   (Enquiry 12121430)Please provide flood boards...             0
# 533548  Please can we supply 3 quotes to do the works ...             1
#
#                        JobStatusName PriorityID PriorityName  \
# 200                    Work Complete       28DY      28 days
# 1038                   Work Complete       28DY      28 days
# 1039                   Work Complete       28DY      28 days
# 242883                 Work Complete        2HR      2 hours
# 292337         Substantiation Passed       28DY      28 days
# 292406                    Job Closed       28DY      28 days
# 533535                 Work Complete       24HR     24 Hours
# 533548  Post Compl Inspection Passed       3MON     3 Months
#
#            ActualCompletionDateTime RouteID ParameterTypeID ParameterValueID  \
# 200     2023-02-11 06:00:00.0000000    A347            %FUL               NK
# 1038    2022-03-29 09:47:20.0000000    4267            %FUL             5075
# 1039    2022-03-29 09:46:19.0000000    4266            %FUL             5075
# 242883  2021-11-17 14:49:16.0000000    3006            %FUL             2550
# 292337  2023-03-18 22:28:00.0000000     R25            %FUL             2550
# 292406  2022-02-11 05:00:00.0000000     R27            %FUL             7510
# 533535  2022-10-21 15:07:56.0000000    3803            %FUL             7510
# 533548  2023-02-22 12:52:31.0000000    3603            %FUL               NK
#
#                ExtractTimestamp  Failure_or_Maintenance prefix  full_failure  \
# 200     2023-04-21 10:59:09.627                       1   SO03             0
# 1038    2023-04-21 10:59:09.627                       1   SE04             0
# 1039    2023-04-21 10:59:09.627                       1   SE04             0
# 242883  2023-04-21 10:59:09.627                       1   SW21             0
# 292337  2023-04-21 10:59:09.627                       1   MD07             0
# 292406  2023-04-21 10:59:09.627                       1   MD07             0
# 533535  2023-04-21 10:59:09.627                       1   SW21             0
# 533548  2023-04-21 10:59:09.627                       1   SW21             0
#
#         covered_failure  broken_failure
# 200                   0               0
# 1038                  0               0
# 1039                  0               0
# 242883                0               0
# 292337                0               0
# 292406                0               0
# 533535                0               0
# 533548                0               0

# %%
final_interventions = final_interventions.drop(columns=["Notes","JobStatusName","PriorityID","PriorityName","ParameterTypeID","EntryDateTime"])

# %%
final_interventions
# Out:
#            JobID        CentralAssetID  FloodHotspot  \
# 0       12000016      A12SDRGU00004594             0
# 1       12002351         A12GU00010060             0
# 2       12002726         A12GU00019535             0
# 3       12002785         A12GU00011223             0
# 4       12003189         A12GU00005763             0
# ...          ...                   ...           ...
# 568710  58156828  DR/HEA10/DRGU/043753             0
# 568711  58156829  DR/HEA10/DRGU/043747             0
# 568712  58156830  DR/HEA10/DRGU/043748             0
# 568713  58156831  DR/HEA10/DRGU/043746             0
# 568714  58156832  DR/HEA10/DRGU/043718             0
#
#            ActualCompletionDateTime RouteID ParameterValueID  \
# 0       2021-06-19 08:07:55.0000000    NO76             7510
# 1       2021-11-09 04:03:52.0000000    NO96             0-25
# 2       2021-11-24 14:18:34.0000000    NO87             2550
# 3       2021-12-08 07:31:56.0000000    NO87               NK
# 4       2022-07-26 01:01:43.0000000    NO41             7510
# ...                             ...     ...              ...
# 568710  2023-04-02 22:21:00.0000000    M128             2550
# 568711  2023-04-02 22:37:09.0000000    M128             2550
# 568712  2023-04-02 22:36:46.0000000    M128             2550
# 568713  2023-04-02 22:37:33.0000000    M128             2550
# 568714  2023-04-02 22:54:58.0000000    M128             2550
#
#                ExtractTimestamp  Failure_or_Maintenance prefix  full_failure  \
# 0       2023-04-21 10:59:09.627                       1   NE12             1
# 1       2023-04-21 10:59:09.627                       1   NE12             0
# 2       2023-04-21 10:59:09.627                       1   NE12             0
# 3       2023-04-21 10:59:09.627                       1   NE12             0
# 4       2023-04-21 10:59:09.627                       1   NE12             1
# ...                         ...                     ...    ...           ...
# 568710  2023-04-21 10:59:09.627                       0   NW10             0
# 568711  2023-04-21 10:59:09.627                       0   NW10             0
# 568712  2023-04-21 10:59:09.627                       0   NW10             0
# 568713  2023-04-21 10:59:09.627                       0   NW10             0
# 568714  2023-04-21 10:59:09.627                       0   NW10             0
#
#         covered_failure  broken_failure
# 0                     0               0
# 1                     0               1
# 2                     1               1
# 3                     0               1
# 4                     0               1
# ...                 ...             ...
# 568710                0               0
# 568711                0               0
# 568712                0               0
# 568713                0               0
# 568714                0               0
#
# [568716 rows x 12 columns]

# %%
final_interventions
# Out:
#            JobID        CentralAssetID  FloodHotspot ActualCompletionDateTime  \
# 0       12000016      A12SDRGU00004594             0      2021-06-19 08:07:55
# 1       12002351         A12GU00010060             0      2021-11-09 04:03:52
# 2       12002726         A12GU00019535             0      2021-11-24 14:18:34
# 3       12002785         A12GU00011223             0      2021-12-08 07:31:56
# 4       12003189         A12GU00005763             0      2022-07-26 01:01:43
# ...          ...                   ...           ...                      ...
# 568710  58156828  DR/HEA10/DRGU/043753             0      2023-04-02 22:21:00
# 568711  58156829  DR/HEA10/DRGU/043747             0      2023-04-02 22:37:09
# 568712  58156830  DR/HEA10/DRGU/043748             0      2023-04-02 22:36:46
# 568713  58156831  DR/HEA10/DRGU/043746             0      2023-04-02 22:37:33
# 568714  58156832  DR/HEA10/DRGU/043718             0      2023-04-02 22:54:58
#
#        RouteID ParameterValueID         ExtractTimestamp  \
# 0         NO76             7510  2023-04-21 10:59:09.627
# 1         NO96             0-25  2023-04-21 10:59:09.627
# 2         NO87             2550  2023-04-21 10:59:09.627
# 3         NO87               NK  2023-04-21 10:59:09.627
# 4         NO41             7510  2023-04-21 10:59:09.627
# ...        ...              ...                      ...
# 568710    M128             2550  2023-04-21 10:59:09.627
# 568711    M128             2550  2023-04-21 10:59:09.627
# 568712    M128             2550  2023-04-21 10:59:09.627
# 568713    M128             2550  2023-04-21 10:59:09.627
# 568714    M128             2550  2023-04-21 10:59:09.627
#
#         Failure_or_Maintenance prefix  full_failure  covered_failure  \
# 0                            1   NE12             1                0
# 1                            1   NE12             0                0
# 2                            1   NE12             0                1
# 3                            1   NE12             0                0
# 4                            1   NE12             1                0
# ...                        ...    ...           ...              ...
# 568710                       0   NW10             0                0
# 568711                       0   NW10             0                0
# 568712                       0   NW10             0                0
# 568713                       0   NW10             0                0
# 568714                       0   NW10             0                0
#
#         broken_failure  Failure_in_6_monts  Failure_in_6_months
# 0                    0                   0                    0
# 1                    1                   0                    0
# 2                    1                   0                    0
# 3                    1                   0                    0
# 4                    1                   0                    0
# ...                ...                 ...                  ...
# 568710               0                   0                    0
# 568711               0                   0                    0
# 568712               0                   0                    0
# 568713               0                   0                    0
# 568714               0                   0                    0
#
# [568716 rows x 14 columns]

# %%
final_interventions["ActualCompletionDateTime"] =  pd.to_datetime(final_interventions["ActualCompletionDateTime"])
final_interventions["ExtractTimestamp"] = pd.to_datetime(final_interventions["ExtractTimestamp"])

# %%
failure = final_interventions[final_interventions["Failure_or_Maintenance"] == 1]
# Plot the histogram
plt.hist(failure['ActualCompletionDateTime'],bins=100)

# Adding labels and title
plt.xlabel('Date and Time')
plt.ylabel('Frequency')
plt.title('Histogram of Actual Completion Date and Time for Failure Data')

# Display the plot
plt.show()

# %%
maintenance = final_interventions[final_interventions["Failure_or_Maintenance"] == 0]
# Plot the histogram
plt.hist(maintenance['ActualCompletionDateTime'],bins=100)

# Adding labels and title
plt.xlabel('Date and Time')
plt.ylabel('Frequency')
plt.title('Histogram of Actual Completion Date and Time for Mainteance Data')

# Display the plot
plt.show()

# %% [markdown]
# ## Pick up below - failure in 6 months etc

# %% [markdown]
# ### Features
# - Failure in 6 months
# - Failure in 1 year

# %%
from datetime import date
from dateutil.relativedelta import relativedelta
from dateutil import parser

# %%
final_interventions.sort_index(inplace=True)
final_interventions = final_interventions.sort_values(by=['ActualCompletionDateTime'], ascending=True)

# %%
def calc_months_from_present(x):
    diff = relativedelta(x["ExtractTimestamp"],x["ActualCompletionDateTime"])
    return diff.years*12 + diff.months

# %%
final_interventions["months_from_present"] = final_interventions.apply(lambda x: calc_months_from_present(x),axis=1)

# %%
final_interventions
# Out:
#            JobID        CentralAssetID  FloodHotspot ActualCompletionDateTime  \
# 51637   41221299           DRGU/015494             0      2018-04-16 21:08:14
# 51608   41221270           DRGU/015493             0      2018-04-16 21:10:56
# 51645   41221307           DRGU/015193             0      2018-04-16 21:14:07
# 51666   41221328           DRGU/015581             0      2018-04-16 21:17:23
# 51624   41221286           DRGU/015097             0      2018-04-16 21:21:25
# ...          ...                   ...           ...                      ...
# 350804  45749937  DR/HEA10/DRGU/004705             0      2023-04-19 03:23:33
# 350778  45749817  DR/HEA10/DRGU/004614             0      2023-04-19 03:28:39
# 350800  45749929  DR/HEA10/DRGU/004575             0      2023-04-19 03:31:36
# 350799  45749928  DR/HEA10/DRGU/004574             0      2023-04-19 03:40:21
# 350798  45749926  DR/HEA10/DRGU/004540             0      2023-04-19 03:40:46
#
#        RouteID ParameterValueID        ExtractTimestamp  \
# 51637     1301             2550 2023-04-21 10:59:09.627
# 51608     1301             2550 2023-04-21 10:59:09.627
# 51645     1301             5075 2023-04-21 10:59:09.627
# 51666     1301             7510 2023-04-21 10:59:09.627
# 51624     1301             7510 2023-04-21 10:59:09.627
# ...        ...              ...                     ...
# 350804    M018             5075 2023-04-21 10:59:09.627
# 350778    M018             5075 2023-04-21 10:59:09.627
# 350800    M018             7510 2023-04-21 10:59:09.627
# 350799    M018             7510 2023-04-21 10:59:09.627
# 350798    M018             7510 2023-04-21 10:59:09.627
#
#         Failure_or_Maintenance prefix  full_failure  covered_failure  \
# 51637                        0   NW13             0                0
# 51608                        0   NW13             0                0
# 51645                        0   NW13             0                0
# 51666                        0   NW13             0                0
# 51624                        0   NW13             0                0
# ...                        ...    ...           ...              ...
# 350804                       0   NW10             0                0
# 350778                       0   NW10             0                0
# 350800                       0   NW10             0                0
# 350799                       0   NW10             0                0
# 350798                       0   NW10             0                0
#
#         broken_failure  Failure_in_6_monts  Failure_in_6_months  \
# 51637                0                   0                    0
# 51608                0                   0                    0
# 51645                0                   0                    0
# 51666                0                   0                    0
# 51624                0                   0                    0
# ...                ...                 ...                  ...
# 350804               0                   0                    0
# 350778               0                   0                    0
# 350800               0                   0                    0
# 350799               0                   0                    0
# 350798               0                   0                    0
#
#         months_from_present
# 51637                    60
# 51608                    60
# 51645                    60
# 51666                    60
# 51624                    60
# ...                     ...
# 350804                    0
# 350778                    0
# 350800                    0
# 350799                    0
# 350798                    0
#
# [568716 rows x 15 columns]

# %%
def add_static_columns_to_output(row,output_dict):
    output_dict["CentralAssetID"].append(row["CentralAssetID"])
    output_dict["FloodHotspot"].append(row["FloodHotspot"])
    output_dict["RouteID"].append(row["RouteID"])
    output_dict["ParameterValueID"].append(row["ParameterValueID"])
    output_dict["prefix"].append(row["prefix"])
    return output_dict

# %%
def add_permutations_to_dict_most_recent(row,output_dict):
    if (row["full_failure"] == 1)&(row["covered_failure"] == 0)&(row["covered_failure"] == 0):
        output_dict["Full_Failure_in_most_recent_6_months"].append(1)
        output_dict["Covered_Failure_in_most_recent_6_months"].append(0)
        output_dict["Broken_Failure_in_most_recent_6_months"].append(0)
        #[1,0,0]
    elif (row["full_failure"] == 0)&(row["covered_failure"] == 1)&(row["covered_failure"] == 0):
        output_dict["Full_Failure_in_most_recent_6_months"].append(0)
        output_dict["Covered_Failure_in_most_recent_6_months"].append(1)
        output_dict["Broken_Failure_in_most_recent_6_months"].append(0)
        #[0,1,0]
    elif (row["full_failure"] == 0)&(row["covered_failure"] == 0)&(row["covered_failure"] == 1):
        output_dict["Full_Failure_in_most_recent_6_months"].append(0)
        output_dict["Covered_Failure_in_most_recent_6_months"].append(0)
        output_dict["Broken_Failure_in_most_recent_6_months"].append(1)
        #[0,0,1]
    elif (row["full_failure"] == 1)&(row["covered_failure"] == 1)&(row["covered_failure"] == 0):
        output_dict["Full_Failure_in_most_recent_6_months"].append(1)
        output_dict["Covered_Failure_in_most_recent_6_months"].append(1)
        output_dict["Broken_Failure_in_most_recent_6_months"].append(0)
        #[1,1,0]
    elif (row["full_failure"] == 0)&(row["covered_failure"] == 1)&(row["covered_failure"] == 1):
        output_dict["Full_Failure_in_most_recent_6_months"].append(0)
        output_dict["Covered_Failure_in_most_recent_6_months"].append(1)
        output_dict["Broken_Failure_in_most_recent_6_months"].append(1)
        #[0,1,1]
    elif (row["full_failure"] == 1)&(row["covered_failure"] == 0)&(row["covered_failure"] == 1):
        output_dict["Full_Failure_in_most_recent_6_months"].append(1)
        output_dict["Covered_Failure_in_most_recent_6_months"].append(0)
        output_dict["Broken_Failure_in_most_recent_6_months"].append(1)
        #[1,0,1]
    elif (row["full_failure"] == 1)&(row["covered_failure"] == 1)&(row["covered_failure"] == 1):
        output_dict["Full_Failure_in_most_recent_6_months"].append(1)
        output_dict["Covered_Failure_in_most_recent_6_months"].append(1)
        output_dict["Broken_Failure_in_most_recent_6_months"].append(1)
        #[1,1,1]
    else:
        output_dict["Full_Failure_in_most_recent_6_months"].append(0)
        output_dict["Covered_Failure_in_most_recent_6_months"].append(0)
        output_dict["Broken_Failure_in_most_recent_6_months"].append(0)
        #[0,0,0]
    return row, output_dict

# %%
def add_permutations_to_dict_previous(row,output_dict):
    if (row["full_failure"] == 1)&(row["covered_failure"] == 0)&(row["covered_failure"] == 0):
        output_dict["Full_Failure_in_previous_6_months"].append(1)
        output_dict["Covered_Failure_in_previous_6_months"].append(0)
        output_dict["Broken_Failure_in_previous_6_months"].append(0)
        #[1,0,0]
    elif (row["full_failure"] == 0)&(row["covered_failure"] == 1)&(row["covered_failure"] == 0):
        output_dict["Full_Failure_in_previous_6_months"].append(0)
        output_dict["Covered_Failure_in_previous_6_months"].append(1)
        output_dict["Broken_Failure_in_previous_6_months"].append(0)
        #[0,1,0]
    elif (row["full_failure"] == 0)&(row["covered_failure"] == 0)&(row["covered_failure"] == 1):
        output_dict["Full_Failure_in_previous_6_months"].append(0)
        output_dict["Covered_Failure_in_previous_6_months"].append(0)
        output_dict["Broken_Failure_in_previous_6_months"].append(1)
        #[0,0,1]
    elif (row["full_failure"] == 1)&(row["covered_failure"] == 1)&(row["covered_failure"] == 0):
        output_dict["Full_Failure_in_previous_6_months"].append(1)
        output_dict["Covered_Failure_in_previous_6_months"].append(1)
        output_dict["Broken_Failure_in_previous_6_months"].append(0)
        #[1,1,0]
    elif (row["full_failure"] == 0)&(row["covered_failure"] == 1)&(row["covered_failure"] == 1):
        output_dict["Full_Failure_in_previous_6_months"].append(0)
        output_dict["Covered_Failure_in_previous_6_months"].append(1)
        output_dict["Broken_Failure_in_previous_6_months"].append(1)
        #[0,1,1]
    elif (row["full_failure"] == 1)&(row["covered_failure"] == 0)&(row["covered_failure"] == 1):
        output_dict["Full_Failure_in_previous_6_months"].append(1)
        output_dict["Covered_Failure_in_previous_6_months"].append(0)
        output_dict["Broken_Failure_in_previous_6_months"].append(1)
        #[1,0,1]
    elif (row["full_failure"] == 1)&(row["covered_failure"] == 1)&(row["covered_failure"] == 1):
        output_dict["Full_Failure_in_previous_6_months"].append(1)
        output_dict["Covered_Failure_in_previous_6_months"].append(1)
        output_dict["Broken_Failure_in_previous_6_months"].append(1)
        #[1,1,1]
    else:
        output_dict["Full_Failure_in_previous_6_months"].append(0)
        output_dict["Covered_Failure_in_previous_6_months"].append(0)
        output_dict["Broken_Failure_in_previous_6_months"].append(0)
        #[0,0,0]
    return row, output_dict

# %%
output_dict = {
    "CentralAssetID": [],
    "FloodHotspot": [],
    "RouteID": [],
    "ParameterValueID": [],
    "prefix": [],
    "Full_Failure_in_most_recent_6_months": [],
    "Full_Failure_in_previous_6_months": [],
    "Covered_Failure_in_most_recent_6_months":[],
    "Covered_Failure_in_previous_6_months": [],
    "Broken_Failure_in_most_recent_6_months":[],
    "Broken_Failure_in_previous_6_months": [],
    "Maintenance_in_most_recent_6_months": [],
    "Maintenance_in_previous_6_months": []
}
time_period = 6

for name, group in final_interventions.groupby("CentralAssetID"):
    for index, row in group.iterrows():
        # Failure Events
        if row["Failure_or_Maintenance"] == 1:
            # Events in the most recent 6 months
            if row["months_from_present"] < 6:
                row, output_dict = add_permutations_to_dict_most_recent(row,output_dict)
                output_dict["Full_Failure_in_previous_6_months"].append(0)
                output_dict["Covered_Failure_in_previous_6_months"].append(0)
                output_dict["Broken_Failure_in_previous_6_months"].append(0)
                output_dict = add_static_columns_to_output(row,output_dict)
                output_dict["Maintenance_in_most_recent_6_months"].append(0)
                output_dict["Maintenance_in_previous_6_months"].append(0)
            # Events between 6-12 months old
            elif row["months_from_present"] >= 6 and row["months_from_present"] <= 12:
                row, output_dict = add_permutations_to_dict_previous(row,output_dict)
                output_dict["Full_Failure_in_most_recent_6_months"].append(0)
                output_dict["Covered_Failure_in_most_recent_6_months"].append(0)
                output_dict["Broken_Failure_in_most_recent_6_months"].append(0)
                output_dict = add_static_columns_to_output(row,output_dict)
                output_dict["Maintenance_in_most_recent_6_months"].append(0)
                output_dict["Maintenance_in_previous_6_months"].append(0)
                
        # Maintenance Events
        else:
            # Events in the most recent 6 months
            if row["months_from_present"] < 6:
                output_dict["Maintenance_in_most_recent_6_months"].append(1)
                output_dict["Maintenance_in_previous_6_months"].append(0)
                output_dict = add_static_columns_to_output(row,output_dict)
                output_dict["Full_Failure_in_most_recent_6_months"].append(0)
                output_dict["Full_Failure_in_previous_6_months"].append(0)
                output_dict["Covered_Failure_in_most_recent_6_months"].append(0)
                output_dict["Covered_Failure_in_previous_6_months"].append(0)
                output_dict["Broken_Failure_in_most_recent_6_months"].append(0)
                output_dict["Broken_Failure_in_previous_6_months"].append(0)
    
            # Events between 6-12 months old
            elif row["months_from_present"] >= 6 and row["months_from_present"] <=12:
                output_dict["Maintenance_in_most_recent_6_months"].append(0)
                output_dict["Maintenance_in_previous_6_months"].append(1)
                output_dict = add_static_columns_to_output(row,output_dict)
                output_dict["Full_Failure_in_most_recent_6_months"].append(0)
                output_dict["Full_Failure_in_previous_6_months"].append(0)
                output_dict["Covered_Failure_in_most_recent_6_months"].append(0)
                output_dict["Covered_Failure_in_previous_6_months"].append(0)
                output_dict["Broken_Failure_in_most_recent_6_months"].append(0)
                output_dict["Broken_Failure_in_previous_6_months"].append(0)

# %%
df = pd.DataFrame(output_dict)

# %%
df = df.groupby(["CentralAssetID","FloodHotspot","RouteID","ParameterValueID","prefix"],as_index=False).sum()

# %%
df.Full_Failure_in_previous_6_months.value_counts()
# Out:
# 0    174180
# 1       423
# 2         8
# 3         1
# Name: Full_Failure_in_previous_6_months, dtype: int64

# %% [markdown]
# ### For cyclic maintenance activities I want to keep the ActualCompletionDateTime as the only date.
# ### For Reactive maintenance activities I want to keep the first instance of it as that is the first date when the failure was realised
# ### If one value of the % full values is null then we need to infill that as it should be the same as its one asset and one intervention -- SOLVED -- Turns out IsCurrentFlag was set to 0 for some causing duplicates - Solved with the line below

# %% [markdown]
# ### If 'cyclic' interventions are performed at random, then you can simply compare the outcomes of 'cyclic' intervention versus the outcomes of 'reactive' intervention over a fixed period of time that would be meaningful. The plot below shows that there is more cyclic maintenance in the spring summer and autumn months compared to the winter months. It could be valuable to add a "Season" variable

# %%
import matplotlib.pyplot as plt 
x = interventions[interventions["Failure_or_Maintenance"]==0][["ActualCompletionDateTime"]]
x["ActualCompletionDateTime"] = x["ActualCompletionDateTime"].astype("datetime64")
x.groupby(x["ActualCompletionDateTime"].dt.month).count().plot(kind="bar",figsize=(20,10))
# Out:
# <AxesSubplot: xlabel='ActualCompletionDateTime'>

# %% [markdown]
# ### Import Meaning of the Percentage Full Parameter Values

# %% [markdown]
# ### Full drains can be verified by the percentage full numbers

# %%
ref_dict = {'ParameterValueID':['2550','NK','CLEA','0-25','N/A','7510','5075']
,'Name':['25 - 50% Full','Change Me','Clear','0 - 25% Full','Non Applicable','75 - 100% Full','50 - 75 % Full']}

# %%
ref_table = pd.DataFrame(ref_dict)

# %%
ref_table
# Out:
#   ParameterValueID            Name
# 0             2550   25 - 50% Full
# 1               NK       Change Me
# 2             CLEA           Clear
# 3             0-25    0 - 25% Full
# 4              N/A  Non Applicable
# 5             7510  75 - 100% Full
# 6             5075  50 - 75 % Full

# %% [markdown]
# ## Process Attributes

# %%
attributes.columns
# Out:
# Index(['CentralAssetID', 'AttrHD52', 'AttrHD41', 'AttrHD39', 'AttrHD57',
#        'AttrHD51', 'AttrHD76', 'AttrHD14', 'AttrHD06', 'AttrHD13', 'AttrHD16',
#        'AttrHD17', 'AttrHD07', 'AttrHD19', 'AttrXSP', 'AttrHD05', 'AttrHD04',
#        'ExtractTimestamp'],
#       dtype='object')

# %%
attributes = attributes.drop(columns=["SiteID","PlotNo","AttrNameHD5",
                         "AttrNameHD41","AttrNameHD39","AttrNameHD57",
                         "AttrNameHD51","AttrNameHD76","AttrNameHD14",
                         "AttrNameHD06","AttrNameHD13","AttrNameHD16",
                        "AttrNameHD17","AttrNameHD07","AttrNameHD19",
                        "AttrNameXSP","AttrNameHD05","AttrNameHD04"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [62], in <cell line: 1>()
# ----> 1 attributes = attributes.drop(columns=["SiteID","PlotNo","AttrNameHD5",
#       2                          "AttrNameHD41","AttrNameHD39","AttrNameHD57",
#       3                          "AttrNameHD51","AttrNameHD76","AttrNameHD14",
#       4                          "AttrNameHD06","AttrNameHD13","AttrNameHD16",
#       5                         "AttrNameHD17","AttrNameHD07","AttrNameHD19",
#       6                         "AttrNameXSP","AttrNameHD05","AttrNameHD04"])
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/frame.py:4308, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4178 def drop(
#    4179     self,
#    4180     labels=None,
#    (...)
#    4186     errors="raise",
#    4187 ):
#    4188     """
#    4189     Drop specified labels from rows or columns.
#    4190
#    (...)
#    4306             weight  1.0     0.8
#    4307     """
# -> 4308     return super().drop(
#    4309         labels=labels,
#    4310         axis=axis,
#    4311         index=index,
#    4312         columns=columns,
#    4313         level=level,
#    4314         inplace=inplace,
#    4315         errors=errors,
#    4316     )
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:4153, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151 for axis, labels in axes.items():
#    4152     if labels is not None:
# -> 4153         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4155 if inplace:
#    4156     self._update_inplace(obj)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/generic.py:4188, in NDFrame._drop_axis(self, labels, axis, level, errors)
#    4186         new_axis = axis.drop(labels, level=level, errors=errors)
#    4187     else:
# -> 4188         new_axis = axis.drop(labels, errors=errors)
#    4189     result = self.reindex(**{axis_name: new_axis})
#    4191 # Case for non-unique axis
#    4192 else:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/indexes/base.py:5591, in Index.drop(self, labels, errors)
#    5589 if mask.any():
#    5590     if errors != "ignore":
# -> 5591         raise KeyError(f"{labels[mask]} not found in axis")
#    5592     indexer = indexer[~mask]
#    5593 return self.delete(indexer)
#
# KeyError: "['SiteID' 'PlotNo' 'AttrNameHD5' 'AttrNameHD41' 'AttrNameHD39'\n 'AttrNameHD57' 'AttrNameHD51' 'AttrNameHD76' 'AttrNameHD14'\n 'AttrNameHD06' 'AttrNameHD13' 'AttrNameHD16' 'AttrNameHD17'\n 'AttrNameHD07' 'AttrNameHD19' 'AttrNameXSP' 'AttrNameHD05' 'AttrNameHD04'] not found in axis"

# %%
attributes
# Out:
#           CentralAssetID AttrHD52 AttrHD41 AttrHD39 AttrHD57 AttrHD51  \
# 0       DR/A03/GU/002084      NaN      NaN      NaN      NaN      NaN
# 1       DR/A03/GU/001632      NaN      NaN      NaN      NaN      NaN
# 2       DR/A03/GU/022092      NaN      NaN      NaN      NaN      NaN
# 3       DR/A03/GU/001187      NaN      NaN      NaN      NaN      NaN
# 4       DR/A03/GU/014372      NaN      NaN      NaN      NaN      NaN
# ...                  ...      ...      ...      ...      ...      ...
# 412600    A21DRGU/111880      NaN      NaN      NaN      NaN      NaN
# 412601    A21DRGU/031554      NaN      NaN      NaN      NaN      NaN
# 412602    A21DRGU/031570      NaN      NaN      NaN      NaN      NaN
# 412603    A21DRGU/034946      NaN      NaN      NaN      NaN      NaN
# 412604    A21DRGU/118931      NaN      NaN      NaN      NaN      NaN
#
#         AttrHD76 AttrHD14 AttrHD06 AttrHD13 AttrHD16 AttrHD17 AttrHD07  \
# 0            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...          ...      ...      ...      ...      ...      ...      ...
# 412600       NaN       PC      NaN        N       RE        H      NaN
# 412601       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 412602       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 412603       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 412604       NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        AttrHD19 AttrXSP AttrHD05 AttrHD04         ExtractTimestamp
# 0           NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 1           NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 2           NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 3           NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 4           NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# ...         ...     ...      ...      ...                      ...
# 412600        Y       L       HA       SW  2023-04-21 11:01:34.847
# 412601      NaN       L      NaN      NaN  2023-04-21 11:01:34.847
# 412602      NaN       L      NaN      NaN  2023-04-21 11:01:34.847
# 412603      NaN       R      NaN      NaN  2023-04-21 11:01:34.847
# 412604      NaN       L       HA       SW  2023-04-21 11:01:34.847
#
# [412605 rows x 18 columns]

# %%
len(attributes.CentralAssetID.unique())
# Out:
# 412589

# %%
import numpy as np

# %%
def count_data(row):
    count =0 
    for column in row[1:17]:
        if column == column:
            count += 1 
    return count
            #if column != 'nan':   print(type(column))

# %%
attributes["amount_of_data"] = attributes.apply(lambda x: count_data(x),axis=1)

# %%
a = attributes.groupby("CentralAssetID",as_index=False)["amount_of_data"].max()

# %%
attributes = pd.merge(a,attributes, on=["CentralAssetID","amount_of_data"], how= "left")

# %%
attributes = attributes.drop(columns='amount_of_data')

# %%
len(attributes.CentralAssetID.unique())
# Out:
# 412589

# %%
attribute_names = {"AttributeTypeID":["HD41",
"HD76",
"HD39",
"HD19",
"HD14",
"HD51",
"HD05",
"HD16",
"XSP",
"HD17",
"HD13",
"HD04",
"HD57",
"HD06",
"HD07",
"HD52"],
"AttributeName":["Chamber Shape",
                "Construction year in YYYY",
                "Asset cleaned prior to insp",
                "Grating",
                "Manhole Construction Type",
                "Sump",
                "Drainage Owner",
                "Chamber Shape",
                "XSP Code",
                "Cover Duty",
                "Is Side Entry in item Y/N",
                "Drainage System Type",
                "Cover or grating hinged Y/N",
                "Strategic Drain",
                "Location Type Code",
                "Trapped Gully Outlet"],
"AttributeDescription":["ADMM  Inventory - The shape code of the chamber cross-section"
,"NULL"
,"NULL"
,"ADMM  Inventory - Indicates the presence of a grating"
,"ADMM  Inventory - Manhole construction type"
,"ADMM  Inventory - Indicates presence of sump"
,"ADMM  Operational - The owner of the item"
,"ADMM  Inventory - The shape code of the cover"
, "ADMM  Inventory - Defines the location of the asset across the carriageway"
,"ADMM  Inventory - The duty of the cover"
,"NULL"
,"ADMM  Inventory - The type of drainage system"
,"ADMM  Inventory - Indicates whether the cover (or grating) is hinged"
,"NULL"
,"ADMM  Inventory - Location type code"
,"ADMM  Inventory - Gully outlet is trapped"]}

# %%
attribute_names_df = pd.DataFrame(attribute_names)
attribute_names_df
# Out:
#    AttributeTypeID                AttributeName  \
# 0             HD41                Chamber Shape
# 1             HD76    Construction year in YYYY
# 2             HD39  Asset cleaned prior to insp
# 3             HD19                      Grating
# 4             HD14    Manhole Construction Type
# 5             HD51                         Sump
# 6             HD05               Drainage Owner
# 7             HD16                Chamber Shape
# 8              XSP                     XSP Code
# 9             HD17                   Cover Duty
# 10            HD13    Is Side Entry in item Y/N
# 11            HD04         Drainage System Type
# 12            HD57  Cover or grating hinged Y/N
# 13            HD06              Strategic Drain
# 14            HD07           Location Type Code
# 15            HD52         Trapped Gully Outlet
#
#                                  AttributeDescription
# 0   ADMM  Inventory - The shape code of the chambe...
# 1                                                NULL
# 2                                                NULL
# 3   ADMM  Inventory - Indicates the presence of a ...
# 4         ADMM  Inventory - Manhole construction type
# 5        ADMM  Inventory - Indicates presence of sump
# 6           ADMM  Operational - The owner of the item
# 7       ADMM  Inventory - The shape code of the cover
# 8   ADMM  Inventory - Defines the location of the ...
# 9             ADMM  Inventory - The duty of the cover
# 10                                               NULL
# 11      ADMM  Inventory - The type of drainage system
# 12  ADMM  Inventory - Indicates whether the cover ...
# 13                                               NULL
# 14               ADMM  Inventory - Location type code
# 15          ADMM  Inventory - Gully outlet is trapped

# %% [markdown]
# ### Join the data

# %%
attributes
# Out:
#               CentralAssetID AttrHD52 AttrHD41 AttrHD39 AttrHD57 AttrHD51  \
# 0       00000000001000000147      NaN      NaN      NaN      NaN      NaN
# 1       00000000001000000148      NaN      NaN      NaN      NaN      NaN
# 2       00000000001000000149      NaN      NaN      NaN      NaN      NaN
# 3       00000000001000000150      NaN      NaN      NaN      NaN      NaN
# 4       00000000001000000151      NaN      NaN      NaN      NaN      NaN
# ...                      ...      ...      ...      ...      ...      ...
# 412584      eastAB/DRGU/0631      NaN      NaN      NaN      NaN      NaN
# 412585      eastAB/DRGU/0632      NaN      NaN      NaN      NaN      NaN
# 412586      eastAB/DRGU/0633      NaN      NaN      NaN      NaN      NaN
# 412587      eastAB/DRGU/0634      NaN      NaN      NaN      NaN      NaN
# 412588      eastAB/DRGU/0635      NaN      NaN      NaN      NaN      NaN
#
#         AttrHD76 AttrHD14 AttrHD06 AttrHD13 AttrHD16 AttrHD17 AttrHD07  \
# 0            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4            NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...          ...      ...      ...      ...      ...      ...      ...
# 412584       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 412585       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 412586       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 412587       NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 412588       NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#        AttrHD19 AttrXSP AttrHD05 AttrHD04         ExtractTimestamp
# 0           NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 1           NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 2           NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 3           NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 4           NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# ...         ...     ...      ...      ...                      ...
# 412584      NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 412585      NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 412586      NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 412587      NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
# 412588      NaN     NaN      NaN      NaN  2023-04-21 11:01:34.847
#
# [412589 rows x 18 columns]

# %%
interventions
# Out:
#             JobID        CentralAssetID      SiteID    PlotNo AssetTypeID  \
# 0        42887971           DRGU/014058  NW13000193  260022.0        DRGU
# 1        42245464        A21DRGU/056579  SW21001920  260435.0        DRGU
# 2        42243698        A21DRGU/110486  SW21001668  260168.0        DRGU
# 3        42305555        A21DRGU/012776  SW21000794  260004.0        DRGU
# 4        42245486        A21DRGU/056488  SW21001920  260647.0        DRGU
# ...           ...                   ...         ...       ...         ...
# 1022558  58100499  DR/HEA10/DRGU/037501  NW10001791  260018.0        DRGU
# 1022559  46428047        A68DRGU/038025  EA68002592  260013.0        DRGU
# 1022560  49695855    DRGU/A04/P00001921  SE04000113  260083.0        DRGU
# 1022561  42414612        A21DRGU/126640  SW21001788  260104.0        DRGU
# 1022562  46387328        A68DRGU/036734  EA68001373  260147.0        DRGU
#
#          LogNo                EntryDateTime  \
# 0            7  2021-11-05 00:00:00.0000000
# 1            6  2020-07-21 00:00:00.0000000
# 2            6  2020-07-21 00:00:00.0000000
# 3            7  2020-12-11 00:00:00.0000000
# 4            6  2020-07-21 00:00:00.0000000
# ...        ...                          ...
# 1022558      7  2022-04-12 00:00:00.0000000
# 1022559      8  2022-02-16 00:00:00.0000000
# 1022560      9  2021-03-31 07:51:57.8270000
# 1022561      6  2021-07-27 00:00:00.0000000
# 1022562      8  2021-06-20 00:00:00.0000000
#
#                                                      Notes  JobTypeID  \
# 0        4.3.1 Clean empty gullies - verge A66 Link 2 C...         12
# 1        Nov - Jan:   (DR: Gullies - clear covers - RLO...         12
# 2         Nov - Jan: (DR: Gullies - clear covers - RLOS 2)         12
# 3                      DR: Gullies - clear covers - RLOS 2         12
# 4        Nov - Jan:   (DR: Gullies - clear covers - RLO...         12
# ...                                                    ...        ...
# 1022558  4.3.1.1 Gullies; gully emptying, including cle...         12
# 1022559  4.3.1.2 Clean Covers and Clear Obstructions 20...         12
# 1022560  Created by Repeating Jobs Agent using Regime: ...         12
# 1022561  Nov - Jan:  (DR: Gullies - empty & clear cover...         12
# 1022562  4.3.1.1 EMPTY GULLIES CLEAR COVERS ROAD: A12 D...         12
#
#         JobTypeCode  ... ParameterTypeID  ParameterValueID  IsDeletedFlag  \
# 0               A08  ...            %FUL              2550              0
# 1               A08  ...            %FUL              2550              0
# 2               A08  ...            %FUL               NaN              0
# 3               A08  ...            %FUL              CLEA              0
# 4               A08  ...            %FUL              2550              0
# ...             ...  ...             ...               ...            ...
# 1022558         A08  ...            %FUL                NK              0
# 1022559         A08  ...            %FUL                NK              0
# 1022560         A08  ...            %FUL                NK              0
# 1022561         A08  ...            %FUL                NK              0
# 1022562         A08  ...            %FUL                NK              0
#
#         IsCurrentFlag            ValidFromDateTime  \
# 0                   1  2021-12-06 00:00:00.0000000
# 1                   1  2021-03-15 20:37:00.0000000
# 2                   1  2021-10-20 00:00:00.0000000
# 3                   1  2021-03-18 10:12:26.0000000
# 4                   1  2021-03-15 21:22:39.0000000
# ...               ...                          ...
# 1022558             0  2022-04-13 00:00:00.0000000
# 1022559             0  2022-02-17 00:00:00.0000000
# 1022560             0  2021-03-31 07:51:57.8730000
# 1022561             0  2021-10-20 00:00:00.0000000
# 1022562             0  2021-10-20 00:00:00.0000000
#
#                      ValidToDateTime             InsertedDateTime JobItemID  \
# 0        9999-12-31 00:00:00.0000000  2021-12-06 07:06:48.8066667      20.0
# 1        9999-12-31 00:00:00.0000000  2021-03-16 06:30:15.2766667      10.0
# 2        9999-12-31 00:00:00.0000000  2021-10-20 12:49:14.4200000      10.0
# 3        9999-12-31 00:00:00.0000000  2021-03-19 06:24:49.2500000      10.0
# 4        9999-12-31 00:00:00.0000000  2021-03-16 06:30:15.2766667      10.0
# ...                              ...                          ...       ...
# 1022558  2022-09-02 23:59:59.0000000  2022-04-13 06:15:29.7800000       NaN
# 1022559  2022-07-04 23:59:59.0000000  2022-02-17 07:14:26.7966667       NaN
# 1022560  2021-08-04 22:13:57.0000000  2021-04-01 05:39:13.9933333       NaN
# 1022561  2022-03-25 23:59:59.0000000  2021-10-20 12:49:14.4200000       NaN
# 1022562  2021-12-30 23:59:59.0000000  2021-10-20 12:49:14.4200000       NaN
#
#          SorItemID         ExtractTimestamp
# 0         A4.3.1.1  2023-04-21 10:59:09.627
# 1         A4.3.1.2  2023-04-21 10:59:09.627
# 2         A4.3.1.2  2023-04-21 10:59:09.627
# 3         A4.3.1.2  2023-04-21 10:59:09.627
# 4         A4.3.1.2  2023-04-21 10:59:09.627
# ...            ...                      ...
# 1022558        NaN  2023-04-21 10:59:09.627
# 1022559        NaN  2023-04-21 10:59:09.627
# 1022560        NaN  2023-04-21 10:59:09.627
# 1022561        NaN  2023-04-21 10:59:09.627
# 1022562        NaN  2023-04-21 10:59:09.627
#
# [1022563 rows x 30 columns]
